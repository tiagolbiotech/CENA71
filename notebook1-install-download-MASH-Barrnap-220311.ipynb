# %% [markdown]
# # Machines used
#
# ## MacBook Pro Mojave OS
#
# Most tools (except antiSMASH, Nerpa and the ones with webservers) were executed in the MacBook Pro with:
#
# ```
# Processor: 2.4 GHz Intel Core i5, 8 CPUs.
# Memory: 8 GB 2133 MHz LPDDR3.
# ```

# %% [markdown]
# # Installation

# %% [markdown]
# ## Anaconda
#
# We used the command-line install according to `https://docs.anaconda.com/anaconda/install/mac-os/`.
#
# And the packages:
# ```
# conda install  -c omnia subprocess32
# conda install -c bioconda pyfasta
# conda install -c conda-forge biopython
# ```
#
# ## antiSMASH v6.0
#
# AntiSMASH can be installed using Anaconda:
#
# `conda install -c bioconda antismash`
#
# or it is possible to use the webservice for a single genomes, like we did for CENA71.
#
# ## MASH v2.3
#
# `conda install -c bioconda mash`
#
# ## Barrnap 0.9
#
# `conda install -c bioconda -c conda-forge barrnap`

# %% [markdown]
# # Downloading genomes

# %% [markdown]
# ## Inputs
#
# `inputs/wgs_selector_211125.csv` - file with names for cyanobacteria from the NCBI database
#
# `inputs/CENA71.fasta` – genome in fasta format

# %% [markdown]
# ## Loading packages

# %%
import os
import time
from itertools import islice
import pandas as pd
import subprocess
import glob
import string
import re
from pyfasta import Fasta
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq
from Bio.Alphabet import generic_dna

# %% [markdown]
# ## Downloading genomes

# %%
if os.path.exists("./wgs_selector_211125.csv"):
    commands = []
    count = 0
    # !cat ./wgs_selector_211125.csv | tr "\t" "~" | cut -d"~" -f1 | sed 1d > ./ids_211125.txt
    with open("./ids_211125.txt") as ids:
        Lines = ids.readlines()
        for line in Lines:
            prefix = line.strip("\n")[:6]
            command = "wget 'ftp://ftp.ncbi.nlm.nih.gov/sra/wgs_aux/%s/%s/%s/%s.1.fsa_nt.gz' -O - | gunzip > ./%s.fasta"%(prefix[0:2],prefix[2:4],prefix,prefix,prefix)
            commands.append(command)
    table1_handle = open('/Volumes/TFL210426/schneider/fasta_genomes/download_cyanobacteria_211125.sh', "w")
    cmd_df = pd.DataFrame(commands)
    cmd_df.to_csv(table1_handle, sep='\t', index=False, header=False)
    table1_handle.close()

# %% [markdown]
# ```
# sh ./download_cyanobacteria_211125.sh
# ```

# %%
# !cat /Volumes/TFL210426/schneider/fasta_genomes/download_cyanobacteria_211125.sh | wc -l
# Out:
#     3874

# %%
# !ls /Volumes/TFL210426/schneider/fasta_genomes/*.fasta | wc -l
# Out:
#     1365

# %%
temp_downloaded_list = glob.glob("/Volumes/TFL210426/schneider/fasta_genomes/*.fasta")
downloaded_list = []

for genome_path in temp_downloaded_list:
    downloaded_list.append(os.path.basename(genome_path).split('.')[0])
    
downloaded_list
# Out:
# ['AADV02',
#  'WJFC01',
#  'WGLZ01',
#  'WGNO01',
#  'WBKL01',
#  'WBKM01',
#  'WBKN01',
#  'WLWJ01',
#  'WMIA01',
#  'WTFZ01',
#  'WTGE01',
#  'WTHF01',
#  'WTHL01',
#  'WTKN01',
#  'WVIC01',
#  'WVID01',
#  'WVIE01',
#  'JACAEU01',
#  'JACJRZ01',
#  'JACYLX01',
#  'JACYLY01',
#  'JACYMA01',
#  'CABUXT',
#  'CABXCX',
#  'CABUXD01',
#  'CACA01',
#  'AANP01',
#  'AAZV01',
#  'ABRS01',
#  'ABRV01',
#  'ABSE01',
#  'ABYK01',
#  'ACDW01',
#  'ACSK03',
#  'AFXD01',
#  'AGCR01',
#  'AGIK01',
#  'AGIZ01',
#  'AEPQ01',
#  'AESD01',
#  'AFEJ01',
#  'AFJC01',
#  'ACYA01',
#  'ACYB01',
#  'ADXM01',
#  'ALPB01',
#  'ALPC01',
#  'ALPD01',
#  'ALPE01',
#  'ALPF01',
#  'ALPG01',
#  'ALPH01',
#  'ALPI01',
#  'ALPJ01',
#  'ALPK01',
#  'ALPL01',
#  'ALVI01',
#  'ALVJ01',
#  'ALVK01',
#  'ALVL01',
#  'ALVM01',
#  'ALVN01',
#  'ALVO01',
#  'ALVP01',
#  'ALVQ01',
#  'ALVR01',
#  'ALVS01',
#  'ALVT01',
#  'ALVU02',
#  'ALVV02',
#  'ALVW01',
#  'ALVX01',
#  'ALVY01',
#  'ALVZ01',
#  'ALWA01',
#  'ALWB01',
#  'ALWC01',
#  'ALWD01',
#  'AHGV01',
#  'AJTX02',
#  'AJUB01',
#  'AJUS01',
#  'AJUT01',
#  'AJUU01',
#  'AJWF01',
#  'AJYB01',
#  'AJHB01',
#  'AJLJ01',
#  'AJLK01',
#  'AJLL01',
#  'AJLM01',
#  'AJLN01',
#  'AZXL01',
#  'AZYY01',
#  'AXUV01',
#  'AXUW01',
#  'AXUX01',
#  'AXZO01',
#  'BDGE01',
#  'BDQK01',
#  'BDQL01',
#  'BDSG01',
#  'BDSM01',
#  'BDUB01',
#  'BDUC01',
#  'BDUD01',
#  'BAUB01',
#  'BAWS01',
#  'BBPA01',
#  'BBWW01',
#  'BBJB01',
#  'BJCD01',
#  'BJCE01',
#  'BJCF01',
#  'BIMP01',
#  'BIMW01',
#  'BJCH01',
#  'BJCI01',
#  'BJCJ01',
#  'BJCK01',
#  'BJHC01',
#  'BJHD01',
#  'BJHE01',
#  'BEIU01',
#  'BEIV01',
#  'BEYQ01',
#  'BFAC01',
#  'BJKP01',
#  'BHVO01',
#  'BHVP01',
#  'BHVQ01',
#  'BHVR01',
#  'BIFY01',
#  'BHVS01',
#  'AANO01',
#  'AAOK01',
#  'BHVU01',
#  'CZCT02',
#  'CZCS02',
#  'CZDF01',
#  'CVSV01',
#  'CVSW01',
#  'CVSX01',
#  'CVSY01',
#  'CVSZ01',
#  'CZCU02',
#  'CZCZ02',
#  'AAVW01',
#  'AAVU01',
#  'AAUA01',
#  'AATZ01',
#  'AAXW01',
#  'CAFN01',
#  'CAIY01',
#  'CAIO01',
#  'CAIP01',
#  'CAIL01',
#  'CAIM01',
#  'CAIK01',
#  'CAIQ01',
#  'CAIN01',
#  'CAIS01',
#  'CAIH01',
#  'CAII01',
#  'CAIJ01',
#  'CBZS01',
#  'CAQK01',
#  'CAQL01',
#  'CAQM01',
#  'CAQN01',
#  'CDHJ01',
#  'DLDG01',
#  'DLDQ01',
#  'DLEF01',
#  'DLEZ01',
#  'DLGM01',
#  'DLLM01',
#  'DLPW01',
#  'DLSU01',
#  'DLUV01',
#  'DLXW01',
#  'DLZW01',
#  'DMEQ01',
#  'DMJW01',
#  'DVDT01',
#  'DVDU01',
#  'DVDV01',
#  'DVDW01',
#  'DVDX01',
#  'DVDY01',
#  'DVDZ01',
#  'DVEA01',
#  'DVEB01',
#  'DVEC01',
#  'DVED01',
#  'DVEE01',
#  'DVEF01',
#  'DPNP01',
#  'DPOG01',
#  'DQAX01',
#  'DQEB01',
#  'DOBT01',
#  'DOFR01',
#  'DOHO01',
#  'DOIX01',
#  'DOJB01',
#  'DOMQ01',
#  'DOPQ01',
#  'DOPZ01',
#  'DOQK01',
#  'DORF01',
#  'DORG01',
#  'DOVM01',
#  'DOVO01',
#  'DOWB01',
#  'DPEI01',
#  'DPLL01',
#  'DMPD01',
#  'DMPE01',
#  'DMPJ01',
#  'DMXX01',
#  'DMYK01',
#  'DNGG01',
#  'DNGI01',
#  'DNGJ01',
#  'DNLA01',
#  'DNME01',
#  'DNOV01',
#  'DNOW01',
#  'DNOY01',
#  'DNOZ01',
#  'DNRP01',
#  'DNSU01',
#  'DNUG01',
#  'DNXU01',
#  'DNYC01',
#  'DNYD01',
#  'DNYY01',
#  'DNZA01',
#  'DVEG01',
#  'DVEH01',
#  'DYNF01',
#  'DSGY01',
#  'DSMC01',
#  'DSPK01',
#  'DSPW01',
#  'DSPX01',
#  'DSQC01',
#  'DBAX01',
#  'DBCX01',
#  'DBIX01',
#  'DBVD01',
#  'DBVH01',
#  'DBXD01',
#  'DBYM01',
#  'DCNZ01',
#  'DCQC01',
#  'DCSN01',
#  'DDLS01',
#  'DFEL01',
#  'DFQU01',
#  'DFRI01',
#  'DFVO01',
#  'DFYB01',
#  'DGBR01',
#  'DGDG01',
#  'DGDH01',
#  'DIYQ01',
#  'DIYT01',
#  'DDVE01',
#  'DEDY01',
#  'DEEH01',
#  'DEEN01',
#  'DEFJ01',
#  'DEGT01',
#  'DEGZ01',
#  'DESS01',
#  'DESZ01',
#  'DJOE01',
#  'DJQF01',
#  'DJYG01',
#  'DJYZ01',
#  'DKMR01',
#  'DKOB01',
#  'DKOE01',
#  'DKRT01',
#  'DGYA01',
#  'DHMN01',
#  'DSRD01',
#  'DSRU01',
#  'BLJI01',
#  'BLZO01',
#  'BOWF01',
#  'BOXC01',
#  'BOXD01',
#  'BOYO01',
#  'AUMZ01',
#  'AUNA01',
#  'AUSW01',
#  'AOCI01',
#  'AQPY01',
#  'ARCP01',
#  'BOYP01',
#  'ASAK01',
#  'ASSJ01',
#  'ASZQ01',
#  'BPAC01',
#  'APIY01',
#  'APIZ01',
#  'AUZM01',
#  'AVFS01',
#  'AVFT01',
#  'AVFU01',
#  'AVFV01',
#  'AVFW01',
#  'AVFX01',
#  'AVFY01',
#  'AVFZ01',
#  'UCNL01',
#  'UCNM01',
#  'AWNH01',
#  'AXAQ01',
#  'ANFJ01',
#  'ANFQ01',
#  'ANKN01',
#  'ANKO01',
#  'ANKQ01',
#  'ANNX02',
#  'FXBO01',
#  'FXWN01',
#  'FYBH01',
#  'FSSI02',
#  'ASAC01',
#  'ATDS01',
#  'FITM01',
#  'NZVB01',
#  'NZXF01',
#  'NXIB02',
#  'NYUU01',
#  'NYXI01',
#  'NYZI01',
#  'NZED01',
#  'NZHI01',
#  'NZHY01',
#  'NZJI01',
#  'NZKA01',
#  'NZPI01',
#  'NQKW01',
#  'NQKX01',
#  'NQKY01',
#  'NQKZ01',
#  'NQLA01',
#  'NQMD01',
#  'NQME01',
#  'NQMF01',
#  'NRIU01',
#  'NRQW01',
#  'NRTA01',
#  'NSHF01',
#  'NSHT01',
#  'NSII01',
#  'NOLI01',
#  'NOLJ01',
#  'NOLK01',
#  'NOXS01',
#  'NOXT01',
#  'NOXU01',
#  'NOXV01',
#  'NOXW01',
#  'NOXX01',
#  'NPIK01',
#  'NPIL01',
#  'NTFS01',
#  'NMQA01',
#  'NMQB01',
#  'NMQC01',
#  'NMQD01',
#  'NMQE01',
#  'NMQF01',
#  'NMQG01',
#  'NMQH01',
#  'NMQI01',
#  'NMQJ01',
#  'NMQK01',
#  'NKFP01',
#  'NRRY01',
#  'LGSU01',
#  'LADK01',
#  'LAGX01',
#  'LAGY01',
#  'LAGZ01',
#  'LAHA01',
#  'LAHB01',
#  'LAHC01',
#  'LAHD01',
#  'LAHE01',
#  'LAHF01',
#  'LAHG01',
#  'LAHH01',
#  'LAHI01',
#  'LAHJ01',
#  'LAMW01',
#  'LATL02',
#  'LAYT01',
#  'LIRE01',
#  'LIRN01',
#  'LIRO01',
#  'LIUQ01',
#  'LJOP01',
#  'LJOQ01',
#  'LJOS01',
#  'LJOT01',
#  'LJOU01',
#  'LJOV01',
#  'LJOW01',
#  'LJOX01',
#  'LJOY01',
#  'LFEK01',
#  'LICO01',
#  'JNAG01',
#  'JNAH01',
#  'JNAI01',
#  'JNAJ01',
#  'JNAK01',
#  'JNAL01',
#  'JNAM01',
#  'JNAN01',
#  'JNAO01',
#  'JNAP01',
#  'JNAQ01',
#  'JNAR01',
#  'JNAS01',
#  'JNAT01',
#  'JNAU01',
#  'JNAV01',
#  'JNAW01',
#  'JNAX01',
#  'JNAY01',
#  'JNAZ01',
#  'JNBA01',
#  'JNBB01',
#  'JNBC01',
#  'JNBD01',
#  'JNBE01',
#  'LSSA01',
#  'LSYZ01',
#  'LSZA01',
#  'JMIX01',
#  'JMKF01',
#  'JMRP01',
#  'LWAJ01',
#  'LWHC01',
#  'LWRO01',
#  'LWSY01',
#  'LWTK01',
#  'LUBZ01',
#  'JHEG04',
#  'LUGL01',
#  'LUHI01',
#  'LUHJ01',
#  'LUPS01',
#  'LUPT01',
#  'LUPU01',
#  'LUPV01',
#  'LURJ01',
#  'LURK01',
#  'LVHK01',
#  'LVHL01',
#  'LVHM01',
#  'LVHN01',
#  'LVHO01',
#  'LVHP01',
#  'LVHQ01',
#  'LVHR01',
#  'LVHS01',
#  'LVHT01',
#  'LVHU01',
#  'LVHV01',
#  'LJZR01',
#  'LJZT01',
#  'LMTZ01',
#  'JXUO01',
#  'JXYX01',
#  'JYFQ01',
#  'JYON01',
#  'JENA01',
#  'LTEC02',
#  'LUFH02',
#  'JXCA02',
#  'JXQG01',
#  'JSUH01',
#  'JXCB02',
#  'JXDI01',
#  'JTCM02',
#  'JTHE02',
#  'JJML01',
#  'JRFE01',
#  'JSDP01',
#  'MKGP02',
#  'MKZR01',
#  'MKZS01',
#  'MLAW01',
#  'MTAV01',
#  'MTAW01',
#  'MTAX01',
#  'MTBS01',
#  'MTBT01',
#  'MTBU01',
#  'MTPU01',
#  'MTQM01',
#  'MUGG01',
#  'MVDI01',
#  'MVGR01',
#  'MRBY01',
#  'MRBZ01',
#  'MRCA01',
#  'MRCB01',
#  'MRCC01',
#  'MRCD01',
#  'MRCE01',
#  'MRCF01',
#  'MRCG01',
#  'MRUD01',
#  'MVOP01',
#  'MWLD01',
#  'MWLE01',
#  'MWLF01',
#  'MWLG01',
#  'MWMJ01',
#  'MWOO01',
#  'MWOP01',
#  'MWOQ01',
#  'MWOR01',
#  'MWOS01',
#  'MWOT01',
#  'MWOU01',
#  'MWOV01',
#  'MWOW01',
#  'MWOX01',
#  'MWOY01',
#  'MWOZ01',
#  'MWPA01',
#  'MWPC01',
#  'MWPD01',
#  'MWPE01',
#  'MWPF01',
#  'MWPG01',
#  'MOLZ01',
#  'MPMK01',
#  'MPPI01',
#  'MNHI01',
#  'MNIV01',
#  'MNPM02',
#  'MNYZ01',
#  'MNZA01',
#  'MOLN01',
#  'MQTZ01',
#  'LMVE01',
#  'LNAA02',
#  'LNDC01',
#  'LYXA01',
#  'LYXM01',
#  'LZQD01',
#  'MBQX01',
#  'MBQY01',
#  'MBRD01',
#  'MBRE01',
#  'MBRF01',
#  'MCIH01',
#  'LXQD01',
#  'LXQE01',
#  'LXYR01',
#  'MDVL01',
#  'MDZH01',
#  'MJGC01',
#  'JPSP01',
#  'JQFA01',
#  'NJHS01',
#  'NJHT01',
#  'NJHU01',
#  'NJHV01',
#  'NJHW01',
#  'NJHX01',
#  'NJHY01',
#  'NJHZ01',
#  'NJIA01',
#  'NBYN01',
#  'NGZS01',
#  'NGZT01',
#  'NGZU01',
#  'NGZV01',
#  'NGZW01',
#  'NGZX01',
#  'NGZY01',
#  'NGZZ01',
#  'NHAA01',
#  'NHAB01',
#  'NHAC01',
#  'NHAD01',
#  'NHAE01',
#  'NHAF01',
#  'NHAG01',
#  'NHAH01',
#  'NHAI01',
#  'NHAJ01',
#  'NHAK01',
#  'NHBY01',
#  'NHBZ02',
#  'NHDT02',
#  'NHER01',
#  'NHHE02',
#  'NHHS01',
#  'NHIA01',
#  'NHII01',
#  'NHIK01',
#  'NHIL01',
#  'NHJC01',
#  'NHJU02',
#  'NHKA01',
#  'NEED01',
#  'NETF01',
#  'JTJC03',
#  'NAPS01',
#  'JTJD02',
#  'NGAA01',
#  'NGJL01',
#  'NDGV01',
#  'NDHW01',
#  'JFKN01',
#  'JFKO01',
#  'JFKP01',
#  'JFKQ01',
#  'JFKR01',
#  'JFKS01',
#  'JFKT01',
#  'JFKU01',
#  'JFKV01',
#  'JFKW01',
#  'JFKX01',
#  'JFKY01',
#  'JFKZ01',
#  'JFLA01',
#  'JFLB01',
#  'JFLC01',
#  'JFLD01',
#  'JFLE01',
#  'JFLF01',
#  'JFLG01',
#  'JFLH01',
#  'JFLI01',
#  'JFLJ01',
#  'JFLK01',
#  'JFLL01',
#  'JFLM01',
#  'JFLN01',
#  'JFLO01',
#  'JFLP01',
#  'JFLQ01',
#  'JFLR01',
#  'JFLS01',
#  'JFLT01',
#  'JFLU01',
#  'JFLV01',
#  'JFLW01',
#  'JFLX01',
#  'JFLY01',
#  'JFLZ01',
#  'JFMA01',
#  'JFMB01',
#  'JFMC01',
#  'JFMD01',
#  'JFME01',
#  'JFMF01',
#  'JFMG01',
#  'JFMH01',
#  'JFMI01',
#  'JFMJ01',
#  'JFMK01',
#  'JFML01',
#  'JFMM01',
#  'JFMN01',
#  'JFMO01',
#  'JFMP01',
#  'JFMQ01',
#  'JFMR01',
#  'JFMS01',
#  'JFMT01',
#  'JFMU01',
#  'JFMV01',
#  'JFMW01',
#  'JFMX01',
#  'JFMY01',
#  'JFMZ01',
#  'JFNA01',
#  'JFNB01',
#  'JFNC01',
#  'JFND01',
#  'JFNE01',
#  'JFNF01',
#  'JFNG01',
#  'JFNH01',
#  'JFNI01',
#  'JFNJ01',
#  'JFNK01',
#  'JFNL01',
#  'JFNM01',
#  'JFNN01',
#  'JFNO01',
#  'JFNP01',
#  'JFNQ01',
#  'JFNR01',
#  'JFNS01',
#  'JFNT01',
#  'JFNU01',
#  'JFNV01',
#  'JFNW01',
#  'JFNX01',
#  'JFNY01',
#  'JFNZ01',
#  'JFOA01',
#  'JFOB01',
#  'JFOC01',
#  'JFOD01',
#  'JFOE01',
#  'NEXP01',
#  'NAPY01',
#  'PDDM01',
#  'PEBC01',
#  'PEIG01',
#  'PESY01',
#  'PBPY01',
#  'PBVK01',
#  'PBYZ01',
#  'PCGE01',
#  'OMJF01',
#  'OMJX01',
#  'PNKA01',
#  'PNKB01',
#  'PNLJ01',
#  'PHNL01',
#  'PNLN01',
#  'PHQT01',
#  'PHQU01',
#  'PAEP01',
#  'PAEU01',
#  'PAJY01',
#  'PAXG01',
#  'PBHJ01',
#  'PRLH01',
#  'PNLS01',
#  'SLQG01',
#  'SMDP01',
#  'SIHH01',
#  'SHAR01',
#  'SHBS01',
#  'SHBT01',
#  'SHBU01',
#  'SMDQ01',
#  'SJEE01',
#  'SKLP01',
#  'SKRX01',
#  'SKYQ01',
#  'SLAY01',
#  'SLAZ01',
#  'SLGH01',
#  'RCBY01',
#  'RCBZ01',
#  'QVFV01',
#  'SLIG01',
#  'SLIY01',
#  'RDXB01',
#  'RDXC01',
#  'RDXF01',
#  'RDXH01',
#  'RDXJ01',
#  'RDXL01',
#  'RDXR01',
#  'RDXU01',
#  'RDXV01',
#  'RDXX01',
#  'RDYB01',
#  'RDYH01',
#  'RDYI01',
#  'RDYJ01',
#  'RDYK01',
#  'RDYN01',
#  'RDYR01',
#  'RDYS01',
#  'RDYZ01',
#  'RDZA01',
#  'RDZB01',
#  'RDZK01',
#  'RDZO01',
#  'RDZU01',
#  'REAA01',
#  'REAF01',
#  'REAI01',
#  'REAK01',
#  'REAO01',
#  'REAP01',
#  'REAX01',
#  'REAY01',
#  'QZCE01',
#  'QXHD01',
#  'REBL01',
#  'REBM01',
#  'RECH01',
#  'RECJ01',
#  'RECR01',
#  'RECT01',
#  'REDN01',
#  'REEV01',
#  'REEX01',
#  'RFFR01',
#  'RFFV01',
#  'RFHR01',
#  'RFIF01',
#  'RFIT01',
#  'RFLH01',
#  'QUBX01',
#  'RFFC02',
#  'RFMH01',
#  'RFPK01',
#  'RFQT01',
#  'RFQU01',
#  'RFZC01',
#  'RGAE01',
#  'PULD01',
#  'PKDM01',
#  'PKDN01',
#  'QQWA01',
#  'QQWB01',
#  'QQWC01',
#  'QQWD01',
#  'QQWE01',
#  'QOPN01',
#  'QOPO01',
#  'QOPP01',
#  'QOPQ01',
#  'QOPR01',
#  'QOPS01',
#  'QOPT01',
#  'QJUE01',
#  'QJUF01',
#  'QLZQ01',
#  'RGAV01',
#  'RGBH01',
#  'QMEA01',
#  'QHKA01',
#  'PWYK01',
#  'PXCV01',
#  'PXDR01',
#  'PXEF01',
#  'PXEJ01',
#  'PXOH01',
#  'PXPI01',
#  'PXPJ01',
#  'PXPK01',
#  'PXPL01',
#  'PXPM01',
#  'PXPN01',
#  'PXPO01',
#  'PXPP01',
#  'PXPQ01',
#  'PXPR01',
#  'PXPS01',
#  'PXPT01',
#  'PXPU01',
#  'PXPV01',
#  'PXPW01',
#  'PXPX01',
#  'PXPY01',
#  'PXPZ01',
#  'PXQA01',
#  'PXQB01',
#  'PXQC01',
#  'PXQD01',
#  'PXQE01',
#  'PXQF01',
#  'PXQG01',
#  'PXQH01',
#  'PXQI01',
#  'PXVC01',
#  'PXXO01',
#  'PYCI01',
#  'PYEQ01',
#  'PYER01',
#  'PYFY01',
#  'PYGV01',
#  'PGEM01',
#  'QMEB01',
#  'QMEC01',
#  'PGON01',
#  'PGOX01',
#  'PHFO01',
#  'PKGD01',
#  'PKRO01',
#  'PKRP01',
#  'PKRQ01',
#  'PKRR01',
#  'PKRS01',
#  'PKRT01',
#  'PVMC01',
#  'PVWD01',
#  'PVWE01',
#  'PVWF01',
#  'PVWG01',
#  'PVWH01',
#  'PVWI01',
#  'PVWJ01',
#  'PVWK01',
#  'PVWL01',
#  'PVWM01',
#  'PVWN01',
#  'PVWO01',
#  'PVWP01',
#  'PWQB01',
#  'PWRG01',
#  'PWXB01',
#  'PQWO01',
#  'PYVJ01',
#  'QCUN01',
#  'QCUO01',
#  'QCUP01',
#  'QCUQ01',
#  'QCUR01',
#  'QCUS01',
#  'QCUT01',
#  'QCUU01',
#  'QCUV01',
#  'QCUW01',
#  'QCUX01',
#  'QCUY01',
#  'QCUZ01',
#  'QCVA01',
#  'QCVB01',
#  'QCVC01',
#  'QCVD01',
#  'QCVE01',
#  'QCVF01',
#  'QCVG01',
#  'QCVH01',
#  'QCVI01',
#  'QCVJ01',
#  'QCVK01',
#  'QCVL01',
#  'QCVM01',
#  'QCVN01',
#  'QCVO01',
#  'QCVP01',
#  'QCVQ01',
#  'QCVR01',
#  'QCVS01',
#  'QCVT01',
#  'QCVU01',
#  'QCVV01',
#  'QCVW01',
#  'QCVX01',
#  'QCVY01',
#  'QCVZ01',
#  'QCWF01',
#  'PTJN01',
#  'QBLS01',
#  'QBLT01',
#  'QBMC01',
#  'QBMD01',
#  'QBMG01',
#  'QBMH01',
#  'QBMJ01',
#  'QBMK01',
#  'QBML01',
#  'QBMM01',
#  'QBMN01',
#  'QBMP01',
#  'QBMQ01',
#  'QBMS01',
#  'QBTW01',
#  'QBVH01',
#  'QBVI01',
#  'QBVJ01',
#  'QBVK01',
#  'QBVL01',
#  'QBVM01',
#  'QBVN01',
#  'QBVO01',
#  'QBVP01',
#  'QBVQ01',
#  'QBVR01',
#  'QBVS01',
#  'QBVT01',
#  'QBVZ01',
#  'QBWA01',
#  'QBWB01',
#  'QBWC01',
#  'QBWD01',
#  'QBWE01',
#  'QBWF01',
#  'QBWG01',
#  'QBWH01',
#  'QBWI01',
#  ...]

# %%
if os.path.exists("./wgs_selector_211125.csv"):
    commands = []
    count = 0
    # !cat ./wgs_selector_211125.csv | tr "\t" "~" | cut -d"~" -f1 | sed 1d > ./ids_211125.txt
    with open("./ids_211125.txt") as ids:
        Lines = ids.readlines()
        for line in Lines:
            prefix = line.strip("\n")[:6]
            if prefix not in downloaded_list:
                command = "wget https://sra-download.ncbi.nlm.nih.gov/traces/wgs01/wgs_aux/%s/%s/%s/%s.1.fsa_nt.gz -O - | gunzip > ./%s.fasta"%(prefix[0:2],prefix[2:4],prefix,prefix,prefix)
                commands.append(command)
    table1_handle = open('/Volumes/TFL210426/schneider/fasta_genomes/download_cyanobacteria_part2_211125.sh', "w")
    cmd_df = pd.DataFrame(commands)
    cmd_df.to_csv(table1_handle, sep='\t', index=False, header=False)
    table1_handle.close()

# %%
# !cat /Volumes/TFL210426/schneider/fasta_genomes/download_cyanobacteria_part2_211125.sh | wc -l
# Out:
#     2215

# %% [markdown]
# ```
# sh download_cyanobacteria_part2_211125.sh
# ```

# %%
# !ls /Volumes/TFL210426/schneider/fasta_genomes/*.fasta | wc -l
# Out:
#     1659

# %%
if os.path.exists("./wgs_selector_211125.csv"):
    commands = []
    count = 0
    # !cat ./wgs_selector_211125.csv | tr "\t" "~" | cut -d"~" -f1 | sed 1d > ./ids_211125.txt
    with open("./ids_211125.txt") as ids:
        Lines = ids.readlines()
        for line in Lines:
            prefix = line.strip("\n")[:6]
            if prefix not in downloaded_list:
                command = "wget https://sra-download.ncbi.nlm.nih.gov/traces/wgs01/wgs_aux/%s/%s/%s/%s01/%s01.1.fsa_nt.gz -O - | gunzip > ./%s01.fasta"%(prefix[0:2],prefix[2:4],prefix[4:6],prefix,prefix,prefix)
                commands.append(command)
    table1_handle = open('/Volumes/TFL210426/schneider/fasta_genomes/download_cyanobacteria_part3_211221.sh', "w")
    cmd_df = pd.DataFrame(commands)
    cmd_df.to_csv(table1_handle, sep='\t', index=False, header=False)
    table1_handle.close()

# %%
# !cat /Volumes/TFL210426/schneider/fasta_genomes/download_cyanobacteria_part3_211221.sh | wc -l
# Out:
#     2213

# %% [markdown]
# ```
# sh download_cyanobacteria_part3_211221.sh
# ```

# %% [markdown]
# ## Checking for missing genomes to be downloaded manually

# %%
temp_downloaded_list = glob.glob("/Volumes/TFL210426/schneider/fasta_genomes/*.fasta")
downloaded_list = []

for genome_path in temp_downloaded_list:
    downloaded_list.append(os.path.basename(genome_path).split('.')[0])
    
downloaded_list
# Out:
# ['AADV02',
#  'WJFC01',
#  'WGLZ01',
#  'WGNO01',
#  'WBKL01',
#  'WBKM01',
#  'WBKN01',
#  'WLWJ01',
#  'WMIA01',
#  'WTFZ01',
#  'WTGE01',
#  'WTHF01',
#  'WTHL01',
#  'WTKN01',
#  'WVIC01',
#  'WVID01',
#  'WVIE01',
#  'JACAEU01',
#  'JACJRZ01',
#  'JACYLX01',
#  'JACYLY01',
#  'JACYMA01',
#  'CABUCV01',
#  'CABXTM01',
#  'CABSEX01',
#  'CABXSG01',
#  'CABXUT01',
#  'CABXYB01',
#  'CABUXD01',
#  'CABYAP01',
#  'CABYAW01',
#  'CABYEB01',
#  'CABYEL01',
#  'CABYGI01',
#  'CABYIY01',
#  'CABYJE01',
#  'CABYJI01',
#  'CABYKM01',
#  'CABYKV01',
#  'CABYLC01',
#  'CABYLJ01',
#  'CABYLR01',
#  'CABYMM01',
#  'CABYNM01',
#  'CABYNZ01',
#  'CABYPO01',
#  'CABYPR01',
#  'CABYQF01',
#  'CABYQY01',
#  'CABYRK01',
#  'CABYRO01',
#  'CABYRZ01',
#  'CABYSR01',
#  'CABYTO01',
#  'CABYTR01',
#  'CABYUE01',
#  'CABYWN01',
#  'CABYWR01',
#  'CABYWZ01',
#  'CABYXI01',
#  'CABYYN01',
#  'CABYZN01',
#  'CABZBE01',
#  'CACA01',
#  'CABZBP01',
#  'CABZCY01',
#  'CABZEQ01',
#  'CABZFE01',
#  'CABZFV01',
#  'CABZFW01',
#  'CABZHQ01',
#  'CABZJH01',
#  'CABZJX01',
#  'CABZLA01',
#  'CABZNT01',
#  'CABZOU01',
#  'CABZPX01',
#  'CABZQQ01',
#  'CABZRB01',
#  'CABZRX01',
#  'CACAFA01',
#  'CACAIX01',
#  'CACAKA01',
#  'CACAKJ01',
#  'CACAMT01',
#  'CACANT01',
#  'CACAQA01',
#  'CACAQD01',
#  'CACAQF01',
#  'CACAQP01',
#  'CACAQQ01',
#  'CACARF01',
#  'CACARV01',
#  'CACASR01',
#  'CACAST01',
#  'CACATM01',
#  'CACATU01',
#  'CACATZ01',
#  'CACAUG01',
#  'CACAVZ01',
#  'CACAWW01',
#  'CACAXN01',
#  'CACAXR01',
#  'CACAXS01',
#  'CACAYO01',
#  'CACAYX01',
#  'CACAZF01',
#  'CACBAW01',
#  'CACBBE01',
#  'CACBBH01',
#  'CACBBI01',
#  'CACBBJ01',
#  'CACBCR01',
#  'CACBDL01',
#  'CACBDN01',
#  'CACBEF01',
#  'CACBES01',
#  'CACBFH01',
#  'CACBGC01',
#  'CACBGI01',
#  'CACBHP01',
#  'CACBIT01',
#  'CACBJB01',
#  'CACBKH01',
#  'CACBKT01',
#  'CACBOC01',
#  'CACBOU01',
#  'CACBRO01',
#  'CACBRZ01',
#  'CACBSA01',
#  'CACBSY01',
#  'CACBTG01',
#  'CACBTP01',
#  'CACBTY01',
#  'CACBVE01',
#  'CACBVY01',
#  'CACBYI01',
#  'CACDRN01',
#  'CACEAF01',
#  'CACEAS01',
#  'CACEEF01',
#  'CACEFS01',
#  'CACEHU01',
#  'CACEMU01',
#  'CACENO01',
#  'CACEPA01',
#  'CACEPC01',
#  'CACEPF01',
#  'CACEPP01',
#  'CACEPZ01',
#  'CACEQI01',
#  'AANP01',
#  'CACEVR01',
#  'CACEWU01',
#  'CACCCI01',
#  'CACCGY01',
#  'CACCHB01',
#  'CACCIG01',
#  'CACCKF01',
#  'CACCKP01',
#  'CACCSS01',
#  'CACCWM01',
#  'CACCZQ01',
#  'CACDDK01',
#  'CACDDW01',
#  'CACDFY01',
#  'CACDIE01',
#  'CACDJL01',
#  'CACJKR01',
#  'CACJNU01',
#  'CACJOV01',
#  'CACJOW01',
#  'CACJOZ01',
#  'CACJPB01',
#  'CACJQY01',
#  'CACJSF01',
#  'CACJTA01',
#  'CACJTI01',
#  'CACJUL01',
#  'CACJVD01',
#  'CACJVV01',
#  'CACJWO01',
#  'CACJYM01',
#  'CACJYO01',
#  'CACJZI01',
#  'CACKAH01',
#  'CACKBB01',
#  'CACKBW01',
#  'CACKEF01',
#  'CACKEW01',
#  'CACKFN01',
#  'CACKFR01',
#  'CACKFT01',
#  'CACKGR01',
#  'CACKHE01',
#  'CACKHG01',
#  'CACKHU01',
#  'CACKIA01',
#  'CACKIP01',
#  'CACKIV01',
#  'CACKJA01',
#  'CACKJL01',
#  'CACKJM01',
#  'CACKKG01',
#  'CACKKJ01',
#  'CACKLP01',
#  'CACKMQ01',
#  'CACKMT01',
#  'CACKOL01',
#  'CACKPW01',
#  'CACKQL01',
#  'CACKSS01',
#  'CACKUC01',
#  'CACKUH01',
#  'CACKUU01',
#  'CACKWB01',
#  'CACHYK01',
#  'CACHYR01',
#  'CACHZW01',
#  'CACIAM01',
#  'CACIBI01',
#  'CACIBL01',
#  'CACIGP01',
#  'CACIIM01',
#  'CACIIQ01',
#  'CACILY01',
#  'CACINK01',
#  'CACINL01',
#  'CACINM01',
#  'CACIRS01',
#  'CACITH01',
#  'CACIUY01',
#  'CACIVI01',
#  'CACIWI01',
#  'CACIYC01',
#  'CACIYG01',
#  'CACJAC01',
#  'CACJBP01',
#  'CACJCK01',
#  'CACJDX01',
#  'CACJEA01',
#  'CACJFG01',
#  'CACJFL01',
#  'CACJJC01',
#  'CACKZL01',
#  'CACKZX01',
#  'CACKZZ01',
#  'CACLAH01',
#  'CACLAV01',
#  'CACLBR01',
#  'CACLBT01',
#  'CACLCE01',
#  'CACLCP01',
#  'CACLCS01',
#  'CACLDO01',
#  'CACLET01',
#  'CACLFP01',
#  'CACLFQ01',
#  'CACLGH01',
#  'CACLGP01',
#  'CACLGR01',
#  'CACLGU01',
#  'CACLPH01',
#  'CACLPT01',
#  'CACLQL01',
#  'CACLQU01',
#  'CACLRA01',
#  'CACLRT01',
#  'CACLTA01',
#  'CACLUB01',
#  'CACLUD01',
#  'CACLUE01',
#  'CACLWO01',
#  'CACLXQ01',
#  'CACLYB01',
#  'CACLYD01',
#  'CACLYT01',
#  'CACLYZ01',
#  'CACMAP01',
#  'CACMAV01',
#  'CACMBG01',
#  'CACMCA01',
#  'CACMDI01',
#  'CACMDN01',
#  'CACMDV01',
#  'CACMJF01',
#  'CACMKY01',
#  'CACMLG01',
#  'CACMLO01',
#  'CACMNZ01',
#  'CACMOD01',
#  'CACMQW01',
#  'CACMRI01',
#  'CACMSA01',
#  'CACMSM01',
#  'CACMTC01',
#  'CACMTE01',
#  'CACMTJ01',
#  'CACMTS01',
#  'CACMUV01',
#  'CACMXO01',
#  'CACMYI01',
#  'CACMZV01',
#  'CACNAG01',
#  'CACNAI01',
#  'CACNAS01',
#  'CACNCC01',
#  'CACNCF01',
#  'CACNDQ01',
#  'CACNEE01',
#  'CACNFQ01',
#  'CACNFR01',
#  'CACNGR01',
#  'CACNJU01',
#  'CACNJX01',
#  'CACNMD01',
#  'CACNMF01',
#  'CACNMX01',
#  'CACNNF01',
#  'CACNPL01',
#  'CACNQB01',
#  'CACNQI01',
#  'CACNQS01',
#  'CACNQT01',
#  'CACNSB01',
#  'CACNSF01',
#  'CACNSG01',
#  'CACNSV01',
#  'CACNUB01',
#  'CACNUL01',
#  'CACGMX01',
#  'CACGNA01',
#  'CACGNH01',
#  'CACGNS01',
#  'CACGOG01',
#  'CACGPQ01',
#  'CACGRX01',
#  'CACGSV01',
#  'CACGTI01',
#  'CACGVZ01',
#  'CACHAH01',
#  'CACHDC01',
#  'CACHDE01',
#  'CACHDL01',
#  'CACHEM01',
#  'CACHGL01',
#  'CACHGM01',
#  'CACHJG01',
#  'CACHKB01',
#  'CACHMM01',
#  'CACHMO01',
#  'CACHMR01',
#  'CACHNH01',
#  'CACHPH01',
#  'CACHQH01',
#  'CACHQJ01',
#  'CACHRC01',
#  'CACHRD01',
#  'CACHSO01',
#  'CACHST01',
#  'CACHTY01',
#  'CACHUE01',
#  'CACHUM01',
#  'CACHUV01',
#  'CACHVD01',
#  'CACHVU01',
#  'CACHXJ01',
#  'CACHXS01',
#  'CACHXX01',
#  'CACEZU01',
#  'CACFAG01',
#  'CACFAJ01',
#  'CACFBG01',
#  'CACFCB01',
#  'CACFDU01',
#  'CACFEJ01',
#  'CACFFG01',
#  'CACFHT01',
#  'CACFLN01',
#  'CACFMC01',
#  'CACFRT01',
#  'CACFSS01',
#  'CACFWF01',
#  'CACFYM01',
#  'CACFZG01',
#  'CACGAJ01',
#  'CACGAP01',
#  'CACGAY01',
#  'CACGBL01',
#  'CACGBQ01',
#  'CACGBT01',
#  'CACGCE01',
#  'CACGCM01',
#  'CACGCN01',
#  'CACGDL01',
#  'CACGEL01',
#  'CACGER01',
#  'CACGFD01',
#  'CACGFK01',
#  'CACGFP01',
#  'CACGFX01',
#  'CACGGL01',
#  'CACGGY01',
#  'CACGHD01',
#  'CACGHI01',
#  'CACGHM01',
#  'CACGHR01',
#  'CACGIB01',
#  'CACGIK01',
#  'CACGJI01',
#  'CACGJP01',
#  'CACGKI01',
#  'CACGKN01',
#  'CACGKT01',
#  'CACGLB01',
#  'CACNVU01',
#  'CACNWD01',
#  'CACNWG01',
#  'CACNWH01',
#  'CACNYU01',
#  'CACOAG01',
#  'CACOAN01',
#  'CACOAY01',
#  'CACOBU01',
#  'CACOCO01',
#  'CACOCT01',
#  'CACOER01',
#  'CACOEX01',
#  'CACOFD01',
#  'CACOFK01',
#  'CACOFO01',
#  'CACOFR01',
#  'CACOHO01',
#  'CACOIJ01',
#  'CACOIM01',
#  'CACOIV01',
#  'AAZV01',
#  'CACOIW01',
#  'ABRS01',
#  'ABRV01',
#  'ABSE01',
#  'ABYK01',
#  'ACDW01',
#  'ACSK03',
#  'AFXD01',
#  'AGCR01',
#  'AGIK01',
#  'AGIZ01',
#  'AEPQ01',
#  'AESD01',
#  'AFEJ01',
#  'AFJC01',
#  'ACYA01',
#  'ACYB01',
#  'ADXM01',
#  'ALPB01',
#  'ALPC01',
#  'ALPD01',
#  'ALPE01',
#  'ALPF01',
#  'ALPG01',
#  'ALPH01',
#  'ALPI01',
#  'ALPJ01',
#  'ALPK01',
#  'ALPL01',
#  'ALVI01',
#  'ALVJ01',
#  'ALVK01',
#  'ALVL01',
#  'ALVM01',
#  'ALVN01',
#  'ALVO01',
#  'ALVP01',
#  'ALVQ01',
#  'ALVR01',
#  'ALVS01',
#  'ALVT01',
#  'ALVU02',
#  'ALVV02',
#  'ALVW01',
#  'ALVX01',
#  'ALVY01',
#  'ALVZ01',
#  'ALWA01',
#  'ALWB01',
#  'ALWC01',
#  'ALWD01',
#  'AHGV01',
#  'AJTX02',
#  'AJUB01',
#  'AJUS01',
#  'AJUT01',
#  'AJUU01',
#  'AJWF01',
#  'AJYB01',
#  'AJHB01',
#  'AJLJ01',
#  'AJLK01',
#  'AJLL01',
#  'AJLM01',
#  'AJLN01',
#  'AZXL01',
#  'AZYY01',
#  'AXUV01',
#  'AXUW01',
#  'AXUX01',
#  'AXZO01',
#  'BDGE01',
#  'BDQK01',
#  'BDQL01',
#  'BDSG01',
#  'BDSM01',
#  'BDUB01',
#  'BDUC01',
#  'BDUD01',
#  'BAUB01',
#  'BAWS01',
#  'CACOIZ01',
#  'BBPA01',
#  'BBWW01',
#  'CACOMD01',
#  'BBJB01',
#  'BJCD01',
#  'BJCE01',
#  'BJCF01',
#  'BIMP01',
#  'BIMW01',
#  'BJCH01',
#  'BJCI01',
#  'BJCJ01',
#  'BJCK01',
#  'BJHC01',
#  'BJHD01',
#  'BJHE01',
#  'BEIU01',
#  'BEIV01',
#  'BEYQ01',
#  'BFAC01',
#  'BJKP01',
#  'CACOPF01',
#  'BHVO01',
#  'BHVP01',
#  'BHVQ01',
#  'BHVR01',
#  'BIFY01',
#  'BHVS01',
#  'AANO01',
#  'AAOK01',
#  'BHVU01',
#  'CZCT02',
#  'CACOQT01',
#  'CZCS02',
#  'CZDF01',
#  'CVSV01',
#  'CVSW01',
#  'CVSX01',
#  'CVSY01',
#  'CVSZ01',
#  'CZCU02',
#  'CZCZ02',
#  'CACOXH01',
#  'CACOYJ01',
#  'CACPBT01',
#  'CACPFL01',
#  'CACPHQ01',
#  'CACPIH01',
#  'CACPJY01',
#  'CACPKH01',
#  'CACPLK01',
#  'CACPNN01',
#  'CACPNZ01',
#  'CABQEX01',
#  'CACVCJ01',
#  'CAJQOK01',
#  'CAJQPG01',
#  'CAJQPQ01',
#  'CAJGYW01',
#  'CAJHBF01',
#  'CAJHBU01',
#  'CAJWHY01',
#  'CAJWLE01',
#  'CAJWTR01',
#  'AAVW01',
#  'AAVU01',
#  'AAUA01',
#  'AATZ01',
#  'AAXW01',
#  'CAFN01',
#  'CAJWYF01',
#  'CAJWYY01',
#  'CAJWZW01',
#  'CAIVJC01',
#  'CAIVMB01',
#  'CAIVMI01',
#  'CAIVPT01',
#  'CAIVSA01',
#  'CAIVSM01',
#  'CAIVTY01',
#  'CAIVUW01',
#  'CAIVVJ01',
#  'CAIWDD01',
#  'CAIWES01',
#  'CAIWEU01',
#  'CAIWHD01',
#  'CAIWIR01',
#  'CAIWKG01',
#  'CAIWLC01',
#  'CAIWNN01',
#  'CAIWPA01',
#  'CAIWSY01',
#  'CAIYIN01',
#  'CAIYJT01',
#  'CAIYLM01',
#  'CAIYRW01',
#  'CAIYSK01',
#  'CAIZCV01',
#  'CAIZDC01',
#  'CAIZIV01',
#  'CAIZKS01',
#  'CAIY01',
#  'CAIZLY01',
#  'CAIZNP01',
#  'CAIZNS01',
#  'CAIZOI01',
#  'CAIZOZ01',
#  'CAIZPV01',
#  'CAIZQP01',
#  'CAIZQU01',
#  'CAIZRB01',
#  'CAIZSN01',
#  'CAIWUP01',
#  'CAIXBB01',
#  'CAIXKS01',
#  'CAIXKU01',
#  'CAIXLN01',
#  'CAIXOZ01',
#  'CAIYEC01',
#  'CAIYEE01',
#  'CAISKX01',
#  'CAISPN01',
#  'CAISRP01',
#  'CAISRT01',
#  'CAISRW01',
#  'CAISTM01',
#  'CAISWB01',
#  'CAISZF01',
#  'CAISZL01',
#  'CAITCA01',
#  'CAITFR01',
#  'CAITHH01',
#  'CAITND01',
#  'CAITOU01',
#  'CAITZL01',
#  'CAIUAQ01',
#  'CAIUCS01',
#  'CAIUMG01',
#  'CAIUQY01',
#  'CAIVAU01',
#  'CAIVFS01',
#  'CAJBJJ01',
#  'CAJBJR01',
#  'CAJBKJ01',
#  'CAJBMA01',
#  'CAJBPY01',
#  'CAJBUV01',
#  'CAJBWW01',
#  'CAJBXU01',
#  'CAJCBE01',
#  'CAJCBZ01',
#  'CAJCFH01',
#  'CAJCFS01',
#  'CAJCFV01',
#  'CAIZWK01',
#  'CAIZXA01',
#  'CAIZXO01',
#  'CAJAAI01',
#  'CAJABW01',
#  'CAJACU01',
#  'CAIO01',
#  'CAJAIC01',
#  'CAJAKH01',
#  'CAJAKO01',
#  'CAJAKS01',
#  'CAJALB01',
#  'CAJALZ01',
#  'CAJAQB01',
#  'CAIP01',
#  'CAJARI01',
#  'CAJATQ01',
#  'CAIL01',
#  'CAJATR01',
#  'CAJAVH01',
#  'CAJAYV01',
#  'CAJAZF01',
#  'CAJAZO01',
#  'CAJBFY01',
#  'CAINZT01',
#  'CAIOBR01',
#  'CAIOCZ01',
#  'CAIOGZ01',
#  'CAIOIS01',
#  'CAIOPL01',
#  'CAIM01',
#  'CAIOXF01',
#  'CAIOXZ01',
#  'CAIPDK01',
#  'CAIKZL01',
#  'CAILBA01',
#  'CAILFB01',
#  'CAILFC01',
#  'CAIK01',
#  'CAILHQ01',
#  'CAILIL01',
#  'CAILJR01',
#  'CAILLV01',
#  'CAILMH01',
#  'CAILTN01',
#  'CAILTU01',
#  'CAILUN01',
#  'CAILZV01',
#  'CAIMED01',
#  'CAIQ01',
#  'CAIMEM01',
#  'CAIJRN01',
#  'CAIJSG01',
#  'CAIJVB01',
#  'CAIJWW01',
#  'CAIJZP01',
#  'CAIKEC01',
#  'CAIKFC01',
#  'CAIKSK01',
#  'CAIKSR01',
#  'CAIKWV01',
#  'CAIN01',
#  'CAIPKM01',
#  'CAIPOC01',
#  'CAIPVN01',
#  'CAIPYC01',
#  'CAIPYS01',
#  'CAIQBV01',
#  'CAIQGS01',
#  'CAIQIA01',
#  'CAIQJE01',
#  'CAIQJY01',
#  'CAIQMA01',
#  'CAIQSI01',
#  'CAIQUF01',
#  'CAIMSC01',
#  'CAIMVL01',
#  'CAIMXA01',
#  'CAIS01',
#  'CAINAG01',
#  'CAINGU01',
#  'CAINPA01',
#  'CAIH01',
#  'CAINPH01',
#  'CAINPL01',
#  'CAINTH01',
#  'CAINUV01',
#  'CAII01',
#  'CAIJ01',
#  'CAINUW01',
#  'CAINWI01',
#  'CAINWT01',
#  'CAIQXI01',
#  'CAIRGI01',
#  'CAIRHH01',
#  'CAIRPA01',
#  'CAIRRO01',
#  'CAIRWM01',
#  'CAISAU01',
#  'CAISDG01',
#  'CBZS01',
#  'CAISIH01',
#  'CADCTM01',
#  'CADCTY01',
#  'CAQK01',
#  'CAQL01',
#  'CAQM01',
#  'CAQN01',
#  'CDHJ01',
#  'DLDG01',
#  'DLDQ01',
#  'DLEF01',
#  'DLEZ01',
#  'DLGM01',
#  'DLLM01',
#  'DLPW01',
#  'DLSU01',
#  'DLUV01',
#  'DLXW01',
#  'DLZW01',
#  'DMEQ01',
#  'DMJW01',
#  'CADCTZ01',
#  'CADCWO01',
#  'DVDT01',
#  'DVDU01',
#  'DVDV01',
#  'DVDW01',
#  'DVDX01',
#  'DVDY01',
#  'DVDZ01',
#  'DVEA01',
#  'DVEB01',
#  'DVEC01',
#  'DVED01',
#  'DVEE01',
#  'DVEF01',
#  'DPNP01',
#  'DPOG01',
#  'DQAX01',
#  'DQEB01',
#  'DOBT01',
#  'DOFR01',
#  'DOHO01',
#  'DOIX01',
#  'DOJB01',
#  'DOMQ01',
#  'DOPQ01',
#  'DOPZ01',
#  'DOQK01',
#  'DORF01',
#  'DORG01',
#  'DOVM01',
#  'DOVO01',
#  'DOWB01',
#  'DPEI01',
#  'DPLL01',
#  'DMPD01',
#  'DMPE01',
#  'DMPJ01',
#  'DMXX01',
#  'DMYK01',
#  'DNGG01',
#  'DNGI01',
#  'DNGJ01',
#  'DNLA01',
#  'DNME01',
#  'DNOV01',
#  'DNOW01',
#  'DNOY01',
#  'DNOZ01',
#  'DNRP01',
#  'DNSU01',
#  'DNUG01',
#  'DNXU01',
#  'DNYC01',
#  'DNYD01',
#  'DNYY01',
#  'DNZA01',
#  'DVEG01',
#  'DVEH01',
#  'DYNF01',
#  'DSGY01',
#  'DSMC01',
#  'DSPK01',
#  'DSPW01',
#  'DSPX01',
#  'DSQC01',
#  'DBAX01',
#  'DBCX01',
#  'DBIX01',
#  'DBVD01',
#  'DBVH01',
#  'DBXD01',
#  'DBYM01',
#  'DCNZ01',
#  'DCQC01',
#  'DCSN01',
#  'DDLS01',
#  'DFEL01',
#  'DFQU01',
#  'DFRI01',
#  'DFVO01',
#  'DFYB01',
#  'DGBR01',
#  'DGDG01',
#  'DGDH01',
#  'DIYQ01',
#  'DIYT01',
#  'DDVE01',
#  'DEDY01',
#  'DEEH01',
#  'DEEN01',
#  'DEFJ01',
#  'DEGT01',
#  'DEGZ01',
#  'DESS01',
#  'DESZ01',
#  'DJOE01',
#  'DJQF01',
#  'DJYG01',
#  'DJYZ01',
#  'DKMR01',
#  'DKOB01',
#  'DKOE01',
#  'DKRT01',
#  'DGYA01',
#  'DHMN01',
#  'DSRD01',
#  'DSRU01',
#  'CAIJEA01',
#  'CAIJFA01',
#  'CAIJJB01',
#  'CAJXSQ01',
#  'CAJXVH01',
#  'BLJI01',
#  'BLZO01',
#  'JAABOT01',
#  'JAABRE01',
#  'BOWF01',
#  'BOXC01',
#  'BOXD01',
#  'BOYO01',
#  'AUMZ01',
#  'AUNA01',
#  'AUSW01',
#  'AOCI01',
#  'AQPY01',
#  'ARCP01',
#  'BOYP01',
#  'ASAK01',
#  'ASSJ01',
#  'ASZQ01',
#  'BPAC01',
#  'APIY01',
#  'APIZ01',
#  'AUZM01',
#  'AVFS01',
#  'AVFT01',
#  'AVFU01',
#  'AVFV01',
#  'AVFW01',
#  'AVFX01',
#  'AVFY01',
#  'AVFZ01',
#  'UCNL01',
#  'UCNM01',
#  'AWNH01',
#  'AXAQ01',
#  'ANFJ01',
#  'ANFQ01',
#  'ANKN01',
#  'ANKO01',
#  'ANKQ01',
#  'ANNX02',
#  'FXBO01',
#  'FXWN01',
#  'FYBH01',
#  'FSSI02',
#  'ASAC01',
#  'ATDS01',
#  'JAABRK01',
#  'JAABRM01',
#  'JAABSD01',
#  'JAABSJ01',
#  'JAABST01',
#  'JAABSU01',
#  'JAACDE01',
#  'JAACPM01',
#  'JAACQX01',
#  'JAACSJ01',
#  'JAACTD01',
#  'JAACUG01',
#  'CAACVJ01',
#  'JAAORC01',
#  'JAAORD01',
#  'JAAORE01',
#  'JAAORF01',
#  'JAAORG01',
#  'JAAORH01',
#  'JAAORI01',
#  'JAAORJ01',
#  'JAAORK01',
#  'JAAORL01',
#  'JAAORM01',
#  'JAAORN01',
#  'JAAORO01',
#  'JAAANX01',
#  'JAAAOK01',
#  'JAAGOG01',
#  'JAAHFM01',
#  'JAAHFN01',
#  'JAAHFO01',
#  'JAAHFP01',
#  'JAAHFQ01',
#  'JAAHFR01',
#  'JAAHFS01',
#  'JAAHFT01',
#  'JAAHFU01',
#  'JAAHFV01',
#  'JAAHFW01',
#  'JAAHFX01',
#  'JAAHFY01',
#  'JAAHFZ01',
#  'JAAHGA01',
#  'JAAHGB01',
#  'JAAHGC01',
#  ...]

# %%
if os.path.exists("./wgs_selector_211125.csv"):
    missing_genomes = []
    with open("./ids_211125.txt") as ids:
        Lines = ids.readlines()
        for line in Lines:
            prefix = line.split(",")[0]
            if prefix not in downloaded_list:
                missing_genomes.append(prefix)

# %%
for item in missing_genomes:
    print(item)
# Out:
# CABUXT01
# CABXCX01
# BLAY01
# CAJWIC01
# CAJWIZ01
# CAJWKD01
# CAJWNL01
# CAJWON01
# CAJWSD01
# CAJWUF01
# CAJWVT01
# CAJWWR01
# CAJWXK01
# CAJWXT01
# CAJWZN01
# CAJXAP01
# CAJXBZ01
# CAJXCS01
# CAJXFG01
# CAJXFQ01
# CAJXHD01
# CAJXNZ01
# CAJXOT01
# CAJXPL01
# CAJXVP01
# CAJYAY01
# CAJYBB01
# CAJYBI01
# CAJYBP01
# CAJYBX01
# CAJWAH01
# CAJWDD01
# CAJWDZ01
# BPQA01
# JAAHBQ01
# JAAHFU02
# JAAMUW01
# JAAMUX01
# JACERF01
# JAFASY01
# JAFAVL01
# JADBRW01
# JADBRX01
# JADBRY01
# JADBSA01
# JADBSB01
# JADBSD01
# JADBSE01
# JADBSF01
# JADBSG01
# JADBSH01
# JADBSI01
# JADBSK01
# JADBSL01
# JADBSM01
# JADBSN01
# JADBSO01
# JADBSP01
# JADBSQ01
# JADBSR01
# JADBSS01
# JADBST01
# JADBSU01
# JADBSW01
# JADBSX01
# JADBSY01
# JADBSZ01
# JADBTB01
# JADBTC01
# JADBTD01
# JADBTE01
# JADBTF01
# JADBTG01
# JADBTH01
# JADBTI01
# JADBTJ01
# JADBTK01
# JADBTL01
# JADBTO01
# JADBTP01
# JADBTQ01
# JADBTR01
# JADBTS01
# JADBTT01
# JADBTU01
# JADBTV01
# JADBTW01
# JADBTY01
# JADBTZ01
# JADBUA01
# JADBUD01
# JADBUE01
# JADBUF01
# JADBUH01
# JADBUI01
# JADBUJ01
# JADBUL01
# JADBUM01
# JADBUN01
# JADBUO01
# JADBUP01
# JADBUQ01
# JADBUR01
# JADBUS01
# JADBUT01
# JADBUX01
# JADBUY01
# JADBUZ01
# JADBVC01
# JADBVE01
# JADBVF01
# JADBVG01
# JADBVH01
# JADBVI01
# JADBVJ01
# JADBVK01
# JADBVN01
# JADBVO01
# JADBVP01
# JADBVQ01
# JADBVR01
# JADBVV01
# JADBVW01
# JADBVY01
# JADBWA01
# JADBWB01
# JADBWC01
# JADBWD01
# JADBWE01
# JADBWF01
# JADBWG01
# JADBWH01
# JADBWJ01
# JADBWK01
# JADBWL01
# JADBWM01
# JADBWN01
# JADBWO01
# JADBWQ01
# JADBWR01
# JADBWS01
# JADBWT01
# JADBWU01
# JADBWW01
# JADBWY01
# JADBWZ01
# JAGQHI01
# JAGQHJ01
# JAGQHL01
# JAGVCD01
# JAGVDA01
# JAFIFC01
# JAHCMI01
# JAHHGR01
# JAHHGS01
# JAHHGT01
# JAHHGU01
# JAHHGW01
# JAHHGX01
# JAHHGZ01
# JAHHHA01
# JAHHHB01
# JAHHHC01
# JAHHHD01
# JAHHHG01
# JAHHHH01
# JAHHHI01
# JAHHHJ01
# JAHHHK01
# JAHHHL01
# JAHHHM01
# JAHHHN01
# JAHHHO01
# JAHHHP01
# JAHHHQ01
# JAHHHS01
# JAHHHT01
# JAHHHX01
# JAHHHY01
# JAHHHZ01
# JAHHIA01
# JAHHIB01
# JAHHIE01
# JAHHIF01
# JAHHIG01
# JAHHIH01
# JAHHII01
# JAHHIK01
# JAHHIM01
# JADEWE01
# JAHUZV01
# JAHUZZ01
# JAHQVZ01
# JAHRET01
# JAHREU01
# JAHREV01
# JAHREW01
# JAHREX01
# JAHREY01
# JAHREZ01
# JAHRFA01
# JAHRFB01
# JAHRFC01
# JAHRFD01
# JAHWKX01
# JAEQBX01
# JAEQBY01
# JAEQBZ01
# JAEQCA01
# JAEQCB01
# JAEQCC01
# JAEQCG01
# JAEQCH01
# JAEQCI01
# JAEQCJ01
# JAEQCK01
# JAEQCL01
# JAEQCM01
# JAEQCN01
# JAEQCO01
# JAEQCP01
# JAEQCT01
# JAEQCU01
# JAEQCV01
# JAEQCW01
# JAEQCX01
# JAEQCZ01
# JAEQDA01
# JAEQDC01
# JAEQDD01
# JAEQDE01
# JAEQDF01
# JAEQDG01
# JAEQDH01
# JAEQDI01
# JAEQDJ01
# JAERMH01
# JADWDC01
# NZ_ASZQ01
# NZ_ATDS01
# NZ_AWNH01
# NZ_AXUV01
# NZ_AXUW01
# NZ_AXUX01
# NZ_AXZO01
# NZ_AOCI01
# NZ_APIY01
# NZ_APIZ01
# NZ_AUMZ01
# NZ_AUNA01
# NZ_AUSW01
# NZ_AUZM01
# NZ_AVFS01
# NZ_AVFT01
# NZ_AVFU01
# NZ_AVFV01
# NZ_AVFW01
# NZ_AVFX01
# NZ_AVFY01
# NZ_AVFZ01
# NZ_ANFJ01
# NZ_ANFQ01
# NZ_ANKN01
# NZ_ANKO01
# NZ_ANKQ01
# NZ_ANNX02
# NZ_ALVI01
# NZ_ALVJ01
# NZ_ALVK01
# NZ_ALVL01
# NZ_ALVM01
# NZ_ALVN01
# NZ_ALVO01
# NZ_ALVP01
# NZ_ALVQ01
# NZ_ALVR01
# NZ_ALVS01
# NZ_ALVT01
# NZ_ALVU02
# NZ_ALVV02
# NZ_ALVW01
# NZ_ALVX01
# NZ_ALVY01
# NZ_ALVZ01
# NZ_ALWB01
# NZ_ALWC01
# NZ_ALWD01
# NZ_ASAC01
# NZ_ASAK01
# NZ_ASSJ01
# NZ_AQPY01
# JAIUYC01
# JAIVFQ01
# JAIVFR01
# JAIVFS01
# JAIVFT01
# JAIVFV01
# JAIVFW01
# JAIVFX01
# JAIVFY01
# JAIVFZ01
# JAJDMN01
# JAJDMO01
# JAJDMP01
# JAJDMR01
# NZ_AADV02
# NZ_AANO01
# NZ_AANP01
# NZ_AAOK01
# NZ_AATZ01
# NZ_AAUA01
# NZ_AAVU01
# NZ_AAVW01
# NZ_AAXW01
# NZ_AEPQ01
# NZ_AESD01
# NZ_AFEJ01
# NZ_AFJC01
# NZ_AFXD01
# NZ_ABRS01
# NZ_ABRV01
# NZ_ABSE01
# NZ_ABYK01
# NZ_ACDW01
# NZ_ACSK03
# NZ_ACYA01
# NZ_ACYB01
# NZ_ADXM01
# NZ_AGCR01
# NZ_AGIK01
# NZ_AGIZ01
# NZ_AHGV01
# NZ_AJLJ01
# NZ_AJLK01
# NZ_AJLL01
# NZ_AJLM01
# NZ_AJLN01
# NZ_AJWF01
# NZ_AJYB01
# NZ_NGZS01
# NZ_NGZT01
# NZ_NGZU01
# NZ_NGZV01
# NZ_NGZW01
# NZ_NGZX01
# NZ_NGZY01
# NZ_NGZZ01
# NZ_NHAA01
# NZ_NHAB01
# NZ_NHAC01
# NZ_NHAD01
# NZ_NHAE01
# NZ_NHAF01
# NZ_NHAG01
# NZ_NHAH01
# NZ_NHAI01
# NZ_NHAK01
# NZ_NPIL01
# NZ_NQKW01
# NZ_NQKX01
# NZ_NQKY01
# NZ_NQKZ01
# NZ_NQLA01
# NZ_NQME01
# NZ_NRQW01
# NZ_NRRY01
# NZ_NRTA01
# NZ_NJHS01
# NZ_NJHT01
# NZ_NJHU01
# NZ_NJHV01
# NZ_NJHW01
# NZ_NJHX01
# NZ_NJHY01
# NZ_NJHZ01
# NZ_NJIA01
# NZ_NOLI01
# NZ_NOLJ01
# NZ_NOLK01
# NZ_NOXS01
# NZ_NOXT01
# NZ_NOXU01
# NZ_NOXV01
# NZ_NOXW01
# NZ_NOXX01
# NZ_NGAA01
# NZ_NKFP01
# NZ_NTFS01
# NZ_NMQA01
# NZ_NMQB01
# NZ_NMQC01
# NZ_NMQE01
# NZ_NMQF01
# NZ_NMQG01
# NZ_NMQH01
# NZ_NMQI01
# NZ_NMQJ01
# NZ_PDDM01
# NZ_PEBC01
# NZ_PCGE01
# NZ_PESY01
# NZ_PGEM01
# NZ_PGON01
# NZ_PGOO01
# NZ_PGOP01
# NZ_PGOQ01
# NZ_PGOR01
# NZ_PGOS01
# NZ_PGOT01
# NZ_PGOU01
# NZ_PGOV01
# NZ_PGOW01
# NZ_PGOX01
# NZ_PGOY01
# NZ_PGWP01
# NZ_PHNL01
# NZ_PHNM01
# NZ_PHQT01
# NZ_PHQU01
# NZ_PKGD01
# NZ_PKRO01
# NZ_PKRP01
# NZ_PKRQ01
# NZ_PKRR01
# NZ_PKRS01
# NZ_PKRT01
# NZ_NXIB02
# NZ_FXBO01
# NZ_FXWN01
# NZ_FYBH01
# NZ_MBQX01
# NZ_MBQY01
# NZ_LWAJ01
# NZ_LWHC01
# NZ_LWSY01
# NZ_LYXA01
# NZ_LZQD01
# NZ_LXYR01
# NZ_MJGC01
# NZ_MDZH01
# NZ_MKZR01
# NZ_MKZS01
# NZ_MNPM02
# NZ_MOLN01
# NZ_MOLZ01
# NZ_BDQK01
# NZ_BDQL01
# NZ_BDSG01
# NZ_BDSM01
# NZ_BDUB01
# NZ_BDUC01
# NZ_BDUD01
# NZ_BEIU01
# NZ_BEIV01
# NZ_BEYQ01
# NZ_BFAC01
# NZ_BHVO01
# NZ_BHVP01
# NZ_BHVQ01
# NZ_BHVR01
# NZ_BHVS01
# NZ_BHVU01
# NZ_BIFY01
# NZ_BIMW01
# NZ_BJCD01
# NZ_BJCE01
# NZ_BJCF01
# NZ_BJCH01
# NZ_BJCI01
# NZ_BJCJ01
# NZ_LMTZ01
# NZ_LMVE01
# NZ_LNDC01
# NZ_LSSA01
# NZ_LSYZ01
# NZ_LSZA01
# NZ_LGSU01
# NZ_LIRE01
# NZ_LIRN01
# NZ_LIRO01
# NZ_LIUQ01
# NZ_LUBZ01
# NZ_LUFH02
# NZ_LUHI01
# NZ_LUHJ01
# NZ_LVHK01
# NZ_LVHL01
# NZ_LVHT01
# NZ_LVHU01
# NZ_LVHV01
# JAIMJO01
# JAIMJS01
# JAIMKC01
# JAIMKD01
# JAIMKQ01
# JAIMKT01
# JAIMKV01
# NZ_JQFA01
# NZ_JRFE01
# NZ_JNAG01
# NZ_JNAH01
# NZ_JNAI01
# NZ_JNAJ01
# NZ_JNAK01
# NZ_JNAL01
# NZ_JNAM01
# NZ_JNAN01
# NZ_JNAO01
# NZ_JNAP01
# NZ_JNAQ01
# NZ_JNAR01
# NZ_JNAS01
# NZ_JNAT01
# NZ_JNAU01
# NZ_JNAV01
# NZ_JNAW01
# NZ_JNAX01
# NZ_JNAY01
# NZ_JNAZ01
# NZ_JNBA01
# NZ_JNBB01
# NZ_JNBC01
# NZ_JNBD01
# NZ_JNBE01
# NZ_JSDP01
# NZ_JSUH01
# NZ_JTCM02
# NZ_JTHE02
# NZ_LAGX01
# NZ_LAGY01
# NZ_LAGZ01
# NZ_LAHA01
# NZ_LAHB01
# NZ_LAHC01
# NZ_LAHD01
# NZ_LAHE01
# NZ_LAHF01
# NZ_LAHG01
# NZ_LAHH01
# NZ_LAHI01
# NZ_LAHJ01
# NZ_LATL02
# NZ_JXYX01
# NZ_JYON01
# NZ_JTJC03
# NZ_JTJD02
# NZ_JXCA02
# NZ_JXCB02
# NZ_JXDI01
# NZ_LFEK01
# NZ_BPQA01
# NZ_CACA01
# NZ_CAFN01
# NZ_CAIH01
# NZ_CAII01
# NZ_CAIJ01
# NZ_CAIK01
# NZ_CAIL01
# NZ_CAIM01
# NZ_CAIN01
# NZ_CAIO01
# NZ_CAIP01
# NZ_CAIQ01
# NZ_CAIS01
# NZ_CAIY01
# NZ_CAQK01
# NZ_CAQL01
# NZ_CAQM01
# NZ_CAQN01
# NZ_JHEG04
# NZ_JMIX01
# NZ_JENA01
# NZ_JJML01
# NZ_PXOH01
# NZ_PXVC01
# NZ_PXXO01
# NZ_PYCI01
# JAIEMQ01
# JAIEMW01
# JAIENO01
# JAIERL01
# JAIFKK01
# JAIFKZ01
# JAIFLY01
# JAIFME01
# JAIWOC01
# JAIQCQ01
# JAIQCR01
# NZ_BBWW01
# NZ_BDGE01
# NZ_AZXL01
# NZ_AZYY01
# NZ_BAUB01
# NZ_BAWS01
# NZ_BBJB01
# NZ_BBPA01
# NZ_BLZO01
# NZ_CVSV01
# NZ_CVSW01
# NZ_CVSX01
# NZ_CVSZ01
# NZ_CZCS02
# NZ_CZCT02
# NZ_CZCU02
# NZ_CZCZ02
# NZ_CZDF01
# NZ_BJCK01
# NZ_BJKP01
# NZ_BLAY01
# NZ_BLJI01
# NZ_FITM01
# NZ_MTAV01
# NZ_MTAW01
# NZ_MTAX01
# NZ_MTPU01
# NZ_MTQM01
# NZ_MQTZ01
# NZ_MRBY01
# NZ_MRBZ01
# NZ_MRCA01
# NZ_MRCB01
# NZ_MRCC01
# NZ_MRCD01
# NZ_MRCE01
# NZ_MRCF01
# NZ_MRCG01
# NZ_MVDI01
# NZ_MVGR01
# NZ_MVOP01
# NZ_NBYN01
# NZ_MWLE01
# NZ_MWOO01
# NZ_MWOP01
# NZ_MWOQ01
# NZ_MWOR01
# NZ_MWOS01
# NZ_MWOT01
# NZ_MWOU01
# NZ_MWOV01
# NZ_MWOW01
# NZ_MWOX01
# NZ_MWOY01
# NZ_MWOZ01
# NZ_MWPA01
# NZ_MWPC01
# NZ_MWPD01
# NZ_MWPE01
# NZ_MWPF01
# NZ_MWPG01
# NZ_NAPS01
# NZ_NAPY01
# NZ_NDHW01
# NZ_MPPI01
# NZ_QVFV01
# NZ_PVMC01
# NZ_PVWF01
# NZ_PVWG01
# NZ_PVWJ01
# NZ_PVWK01
# NZ_PVWM01
# NZ_PVWN01
# NZ_PVWO01
# NZ_PVWP01
# NZ_QBTW01
# NZ_PQWO01
# NZ_PRLH01
# NZ_PTJN01
# NZ_RCBY01
# NZ_RCBZ01
# NZ_WJFC01
# NZ_WMIA01
# NZ_WVID01
# NZ_WVIE01
# NZ_SDBW01
# NZ_SELU01
# NZ_QHKA01
# NZ_RJVW01
# NZ_RSCJ01
# NZ_RSCK01
# NZ_RSCL01
# NZ_RSCM01
# NZ_RSCN01
# NZ_QLZQ01
# NZ_QMEA01
# NZ_QMEB01
# NZ_QMEC01
# NZ_VTKW01
# NZ_VTKY01
# NZ_VTKZ01
# NZ_VTLA01
# NZ_VTLB01
# NZ_VTLC01
# NZ_VTLE01
# NZ_VTLF01
# NZ_VTRR01
# NZ_VJXY01
# NZ_VLKB01
# NZ_VLNZ01
# NZ_VNWP01
# NZ_VOBS01
# NZ_VIKV01
# NZ_VIKW01
# NZ_VIKX01
# NZ_VIKY01
# NZ_VIKZ01
# NZ_VILA01
# NZ_VILB01
# NZ_VILC01
# NZ_VILD01
# NZ_VILE01
# NZ_VILF01
# NZ_VIRO01
# NZ_VITZ01
# NZ_WBKL01
# NZ_WBKM01
# NZ_WBKN01
# NZ_VXJX01
# NZ_VUOE01
# NZ_SMDP01
# NZ_SMDQ01
# NZ_RPHB01
# NZ_SZNH01
# NZ_SRLN01
# NZ_SRRZ01
# NZ_UCND01
# NZ_UCNI01
# NZ_UCNJ01
# NZ_UCNL01
# NZ_UCNM01
# NZ_UCNN01
# NZ_UCNR01
# NZ_UCNU01
# NZ_UCNV01
# NZ_UCNW01
# NZ_UCNZ01
# NZ_UCOB01
# NZ_QJUE01
# NZ_QJUF01
# NZ_VFEV01
# NZ_VHLJ01
# NZ_VDFD01
# NZ_VDFE01
# NZ_VDFF01
# NZ_VDFG01
# NZ_SJEE01
# PHNM01
# PGOO01
# PGOP01
# PGOQ01
# PGOR01
# PGOS01
# PGOT01
# PGOU01
# PGOV01
# PGOW01
# PGOY01
# PGWP01
# RPHB01
# VTKX01
# VTKY01
# VTKZ01
# VTLC01
# VTLD01

# %%
for item in missing_genomes:
    if "NZ_" in item:
        new_item = item[3:]
        if new_item in missing_genomes:
            print(new_item)
# Out:
# PGOO01
# PGOP01
# PGOQ01
# PGOR01
# PGOS01
# PGOT01
# PGOU01
# PGOV01
# PGOW01
# PGOY01
# PGWP01
# PHNM01
# BPQA01
# BLAY01
# VTKY01
# VTKZ01
# VTLC01
# RPHB01

# %% [markdown]
# ---

# %%
temp_downloaded_list = glob.glob("/Volumes/TFL210426/schneider/fasta_genomes/*.fasta")
downloaded_list = []

for genome_path in temp_downloaded_list:
    downloaded_list.append(os.path.basename(genome_path).split('.')[0])
    
downloaded_list
# Out:
# ['AADV02',
#  'WJFC01',
#  'WGLZ01',
#  'WGNO01',
#  'WBKL01',
#  'WBKM01',
#  'WBKN01',
#  'WLWJ01',
#  'WMIA01',
#  'WTFZ01',
#  'WTGE01',
#  'WTHF01',
#  'WTHL01',
#  'WTKN01',
#  'WVIC01',
#  'WVID01',
#  'WVIE01',
#  'JACAEU01',
#  'JACJRZ01',
#  'JACYLX01',
#  'JACYLY01',
#  'JACYMA01',
#  'CABUCV01',
#  'CABXTM01',
#  'CABSEX01',
#  'CABXSG01',
#  'CABXUT01',
#  'CABXYB01',
#  'CABUXD01',
#  'CABYAP01',
#  'CABYAW01',
#  'CABYEB01',
#  'CABYEL01',
#  'CABYGI01',
#  'CABYIY01',
#  'CABYJE01',
#  'CABYJI01',
#  'CABYKM01',
#  'CABYKV01',
#  'CABYLC01',
#  'CABYLJ01',
#  'CABYLR01',
#  'CABYMM01',
#  'CABYNM01',
#  'CABYNZ01',
#  'CABYPO01',
#  'CABYPR01',
#  'CABYQF01',
#  'CABYQY01',
#  'CABYRK01',
#  'CABYRO01',
#  'CABYRZ01',
#  'CABYSR01',
#  'CABYTO01',
#  'CABYTR01',
#  'CABYUE01',
#  'CABYWN01',
#  'CABYWR01',
#  'CABYWZ01',
#  'CABYXI01',
#  'CABYYN01',
#  'CABYZN01',
#  'CABZBE01',
#  'CACA01',
#  'CABZBP01',
#  'CABZCY01',
#  'CABZEQ01',
#  'CABZFE01',
#  'CABZFV01',
#  'CABZFW01',
#  'CABZHQ01',
#  'CABZJH01',
#  'CABZJX01',
#  'CABZLA01',
#  'CABZNT01',
#  'CABZOU01',
#  'CABZPX01',
#  'CABZQQ01',
#  'CABZRB01',
#  'CABZRX01',
#  'CACAFA01',
#  'CACAIX01',
#  'CACAKA01',
#  'CACAKJ01',
#  'CACAMT01',
#  'CACANT01',
#  'CACAQA01',
#  'CACAQD01',
#  'CACAQF01',
#  'CACAQP01',
#  'CACAQQ01',
#  'CACARF01',
#  'CACARV01',
#  'CACASR01',
#  'CACAST01',
#  'CACATM01',
#  'CACATU01',
#  'CACATZ01',
#  'CACAUG01',
#  'CACAVZ01',
#  'CACAWW01',
#  'CACAXN01',
#  'CACAXR01',
#  'CACAXS01',
#  'CACAYO01',
#  'CACAYX01',
#  'CACAZF01',
#  'CACBAW01',
#  'CACBBE01',
#  'CACBBH01',
#  'CACBBI01',
#  'CACBBJ01',
#  'CACBCR01',
#  'CACBDL01',
#  'CACBDN01',
#  'CACBEF01',
#  'CACBES01',
#  'CACBFH01',
#  'CACBGC01',
#  'CACBGI01',
#  'CACBHP01',
#  'CACBIT01',
#  'CACBJB01',
#  'CACBKH01',
#  'CACBKT01',
#  'CACBOC01',
#  'CACBOU01',
#  'CACBRO01',
#  'CACBRZ01',
#  'CACBSA01',
#  'CACBSY01',
#  'CACBTG01',
#  'CACBTP01',
#  'CACBTY01',
#  'CACBVE01',
#  'CACBVY01',
#  'CACBYI01',
#  'CACDRN01',
#  'CACEAF01',
#  'CACEAS01',
#  'CACEEF01',
#  'CACEFS01',
#  'CACEHU01',
#  'CACEMU01',
#  'CACENO01',
#  'CACEPA01',
#  'CACEPC01',
#  'CACEPF01',
#  'CACEPP01',
#  'CACEPZ01',
#  'CACEQI01',
#  'AANP01',
#  'CACEVR01',
#  'CACEWU01',
#  'CACCCI01',
#  'CACCGY01',
#  'CACCHB01',
#  'CACCIG01',
#  'CACCKF01',
#  'CACCKP01',
#  'CACCSS01',
#  'CACCWM01',
#  'CACCZQ01',
#  'CACDDK01',
#  'CACDDW01',
#  'CACDFY01',
#  'CACDIE01',
#  'CACDJL01',
#  'CACJKR01',
#  'CACJNU01',
#  'CACJOV01',
#  'CACJOW01',
#  'CACJOZ01',
#  'CACJPB01',
#  'CACJQY01',
#  'CACJSF01',
#  'CACJTA01',
#  'CACJTI01',
#  'CACJUL01',
#  'CACJVD01',
#  'CACJVV01',
#  'CACJWO01',
#  'CACJYM01',
#  'CACJYO01',
#  'CACJZI01',
#  'CACKAH01',
#  'CACKBB01',
#  'CACKBW01',
#  'CACKEF01',
#  'CACKEW01',
#  'CACKFN01',
#  'CACKFR01',
#  'CACKFT01',
#  'CACKGR01',
#  'CACKHE01',
#  'CACKHG01',
#  'CACKHU01',
#  'CACKIA01',
#  'CACKIP01',
#  'CACKIV01',
#  'CACKJA01',
#  'CACKJL01',
#  'CACKJM01',
#  'CACKKG01',
#  'CACKKJ01',
#  'CACKLP01',
#  'CACKMQ01',
#  'CACKMT01',
#  'CACKOL01',
#  'CACKPW01',
#  'CACKQL01',
#  'CACKSS01',
#  'CACKUC01',
#  'CACKUH01',
#  'CACKUU01',
#  'CACKWB01',
#  'CACHYK01',
#  'CACHYR01',
#  'CACHZW01',
#  'CACIAM01',
#  'CACIBI01',
#  'CACIBL01',
#  'CACIGP01',
#  'CACIIM01',
#  'CACIIQ01',
#  'CACILY01',
#  'CACINK01',
#  'CACINL01',
#  'CACINM01',
#  'CACIRS01',
#  'CACITH01',
#  'CACIUY01',
#  'CACIVI01',
#  'CACIWI01',
#  'CACIYC01',
#  'CACIYG01',
#  'CACJAC01',
#  'CACJBP01',
#  'CACJCK01',
#  'CACJDX01',
#  'CACJEA01',
#  'CACJFG01',
#  'CACJFL01',
#  'CACJJC01',
#  'CACKZL01',
#  'CACKZX01',
#  'CACKZZ01',
#  'CACLAH01',
#  'CACLAV01',
#  'CACLBR01',
#  'CACLBT01',
#  'CACLCE01',
#  'CACLCP01',
#  'CACLCS01',
#  'CACLDO01',
#  'CACLET01',
#  'CACLFP01',
#  'CACLFQ01',
#  'CACLGH01',
#  'CACLGP01',
#  'CACLGR01',
#  'CACLGU01',
#  'CACLPH01',
#  'CACLPT01',
#  'CACLQL01',
#  'CACLQU01',
#  'CACLRA01',
#  'CACLRT01',
#  'CACLTA01',
#  'CACLUB01',
#  'CACLUD01',
#  'CACLUE01',
#  'CACLWO01',
#  'CACLXQ01',
#  'CACLYB01',
#  'CACLYD01',
#  'CACLYT01',
#  'CACLYZ01',
#  'CACMAP01',
#  'CACMAV01',
#  'CACMBG01',
#  'CACMCA01',
#  'CACMDI01',
#  'CACMDN01',
#  'CACMDV01',
#  'CACMJF01',
#  'CACMKY01',
#  'CACMLG01',
#  'CACMLO01',
#  'CACMNZ01',
#  'CACMOD01',
#  'CACMQW01',
#  'CACMRI01',
#  'CACMSA01',
#  'CACMSM01',
#  'CACMTC01',
#  'CACMTE01',
#  'CACMTJ01',
#  'CACMTS01',
#  'CACMUV01',
#  'CACMXO01',
#  'CACMYI01',
#  'CACMZV01',
#  'CACNAG01',
#  'CACNAI01',
#  'CACNAS01',
#  'CACNCC01',
#  'CACNCF01',
#  'CACNDQ01',
#  'CACNEE01',
#  'CACNFQ01',
#  'CACNFR01',
#  'CACNGR01',
#  'CACNJU01',
#  'CACNJX01',
#  'CACNMD01',
#  'CACNMF01',
#  'CACNMX01',
#  'CACNNF01',
#  'CACNPL01',
#  'CACNQB01',
#  'CACNQI01',
#  'CACNQS01',
#  'CACNQT01',
#  'CACNSB01',
#  'CACNSF01',
#  'CACNSG01',
#  'CACNSV01',
#  'CACNUB01',
#  'CACNUL01',
#  'CACGMX01',
#  'CACGNA01',
#  'CACGNH01',
#  'CACGNS01',
#  'CACGOG01',
#  'CACGPQ01',
#  'CACGRX01',
#  'CACGSV01',
#  'CACGTI01',
#  'CACGVZ01',
#  'CACHAH01',
#  'CACHDC01',
#  'CACHDE01',
#  'CACHDL01',
#  'CACHEM01',
#  'CACHGL01',
#  'CACHGM01',
#  'CACHJG01',
#  'CACHKB01',
#  'CACHMM01',
#  'CACHMO01',
#  'CACHMR01',
#  'CACHNH01',
#  'CACHPH01',
#  'CACHQH01',
#  'CACHQJ01',
#  'CACHRC01',
#  'CACHRD01',
#  'CACHSO01',
#  'CACHST01',
#  'CACHTY01',
#  'CACHUE01',
#  'CACHUM01',
#  'CACHUV01',
#  'CACHVD01',
#  'CACHVU01',
#  'CACHXJ01',
#  'CACHXS01',
#  'CACHXX01',
#  'CACEZU01',
#  'CACFAG01',
#  'CACFAJ01',
#  'CACFBG01',
#  'CACFCB01',
#  'CACFDU01',
#  'CACFEJ01',
#  'CACFFG01',
#  'CACFHT01',
#  'CACFLN01',
#  'CACFMC01',
#  'CACFRT01',
#  'CACFSS01',
#  'CACFWF01',
#  'CACFYM01',
#  'CACFZG01',
#  'CACGAJ01',
#  'CACGAP01',
#  'CACGAY01',
#  'CACGBL01',
#  'CACGBQ01',
#  'CACGBT01',
#  'CACGCE01',
#  'CACGCM01',
#  'CACGCN01',
#  'CACGDL01',
#  'CACGEL01',
#  'CACGER01',
#  'CACGFD01',
#  'CACGFK01',
#  'CACGFP01',
#  'CACGFX01',
#  'CACGGL01',
#  'CACGGY01',
#  'CACGHD01',
#  'CACGHI01',
#  'CACGHM01',
#  'CACGHR01',
#  'CACGIB01',
#  'CACGIK01',
#  'CACGJI01',
#  'CACGJP01',
#  'CACGKI01',
#  'CACGKN01',
#  'CACGKT01',
#  'CACGLB01',
#  'CACNVU01',
#  'CACNWD01',
#  'CACNWG01',
#  'CACNWH01',
#  'CACNYU01',
#  'CACOAG01',
#  'CACOAN01',
#  'CACOAY01',
#  'CACOBU01',
#  'CACOCO01',
#  'CACOCT01',
#  'CACOER01',
#  'CACOEX01',
#  'CACOFD01',
#  'CACOFK01',
#  'CACOFO01',
#  'CACOFR01',
#  'CACOHO01',
#  'CACOIJ01',
#  'CACOIM01',
#  'CACOIV01',
#  'AAZV01',
#  'CACOIW01',
#  'ABRS01',
#  'ABRV01',
#  'ABSE01',
#  'ABYK01',
#  'ACDW01',
#  'ACSK03',
#  'AFXD01',
#  'AGCR01',
#  'AGIK01',
#  'AGIZ01',
#  'AEPQ01',
#  'AESD01',
#  'AFEJ01',
#  'AFJC01',
#  'ACYA01',
#  'ACYB01',
#  'ADXM01',
#  'ALPB01',
#  'ALPC01',
#  'ALPD01',
#  'ALPE01',
#  'ALPF01',
#  'ALPG01',
#  'ALPH01',
#  'ALPI01',
#  'ALPJ01',
#  'ALPK01',
#  'ALPL01',
#  'ALVI01',
#  'ALVJ01',
#  'ALVK01',
#  'ALVL01',
#  'ALVM01',
#  'ALVN01',
#  'ALVO01',
#  'ALVP01',
#  'ALVQ01',
#  'ALVR01',
#  'ALVS01',
#  'ALVT01',
#  'ALVU02',
#  'ALVV02',
#  'ALVW01',
#  'ALVX01',
#  'ALVY01',
#  'ALVZ01',
#  'ALWA01',
#  'ALWB01',
#  'ALWC01',
#  'ALWD01',
#  'AHGV01',
#  'AJTX02',
#  'AJUB01',
#  'AJUS01',
#  'AJUT01',
#  'AJUU01',
#  'AJWF01',
#  'AJYB01',
#  'AJHB01',
#  'AJLJ01',
#  'AJLK01',
#  'AJLL01',
#  'AJLM01',
#  'AJLN01',
#  'AZXL01',
#  'AZYY01',
#  'AXUV01',
#  'AXUW01',
#  'AXUX01',
#  'AXZO01',
#  'BDGE01',
#  'BDQK01',
#  'BDQL01',
#  'BDSG01',
#  'BDSM01',
#  'BDUB01',
#  'BDUC01',
#  'BDUD01',
#  'BAUB01',
#  'BAWS01',
#  'CACOIZ01',
#  'BBPA01',
#  'BBWW01',
#  'CACOMD01',
#  'BBJB01',
#  'BJCD01',
#  'BJCE01',
#  'BJCF01',
#  'BIMP01',
#  'BIMW01',
#  'BJCH01',
#  'BJCI01',
#  'BJCJ01',
#  'BJCK01',
#  'BJHC01',
#  'BJHD01',
#  'BJHE01',
#  'BEIU01',
#  'BEIV01',
#  'BEYQ01',
#  'BFAC01',
#  'BJKP01',
#  'CACOPF01',
#  'BHVO01',
#  'BHVP01',
#  'BHVQ01',
#  'BHVR01',
#  'BIFY01',
#  'BHVS01',
#  'AANO01',
#  'AAOK01',
#  'BHVU01',
#  'CZCT02',
#  'CACOQT01',
#  'CZCS02',
#  'CZDF01',
#  'CVSV01',
#  'CVSW01',
#  'CVSX01',
#  'CVSY01',
#  'CVSZ01',
#  'CZCU02',
#  'CZCZ02',
#  'CACOXH01',
#  'CACOYJ01',
#  'CACPBT01',
#  'CACPFL01',
#  'CACPHQ01',
#  'CACPIH01',
#  'CACPJY01',
#  'CACPKH01',
#  'CACPLK01',
#  'CACPNN01',
#  'CACPNZ01',
#  'CABQEX01',
#  'BLAY01',
#  'CACVCJ01',
#  'CAJQOK01',
#  'CAJQPG01',
#  'CAJQPQ01',
#  'CAJGYW01',
#  'CAJHBF01',
#  'CAJHBU01',
#  'CAJWHY01',
#  'AATZ01',
#  'BPQA01',
#  'AAUA01',
#  'CAJWLE01',
#  'CABUXT01',
#  'AAVU01',
#  'AAVW01',
#  'CAJWTR01',
#  'CABXCX01',
#  'CAJWAH01',
#  'AAXW01',
#  'ANFJ01',
#  'ANFQ01',
#  'ANKN01',
#  'ANKO01',
#  'CAFN01',
#  'ANKQ01',
#  'ANNX02',
#  'AOCI01',
#  'CAJWYF01',
#  'CAJWYY01',
#  'CAJWDD01',
#  'CAJWZW01',
#  'APIY01',
#  'CAJWDZ01',
#  'APIZ01',
#  'CAJWIC01',
#  'AQPY01',
#  'CAJWIZ01',
#  'ASAC01',
#  'ASAK01',
#  'CAIVJC01',
#  'CAIVMB01',
#  'CAIVMI01',
#  'CAIVPT01',
#  'CAIVSA01',
#  'CAIVSM01',
#  'CAIVTY01',
#  'CAIVUW01',
#  'CAIVVJ01',
#  'CAIWDD01',
#  'CAIWES01',
#  'CAIWEU01',
#  'CAIWHD01',
#  'CAIWIR01',
#  'CAIWKG01',
#  'CAIWLC01',
#  'CAIWNN01',
#  'CAIWPA01',
#  'CAIWSY01',
#  'CAIYIN01',
#  'CAIYJT01',
#  'CAIYLM01',
#  'CAIYRW01',
#  'CAIYSK01',
#  'CAIZCV01',
#  'CAIZDC01',
#  'CAIZIV01',
#  'CAIZKS01',
#  'CAIY01',
#  'CAIZLY01',
#  'CAIZNP01',
#  'CAIZNS01',
#  'CAIZOI01',
#  'CAIZOZ01',
#  'CAIZPV01',
#  'CAIZQP01',
#  'CAIZQU01',
#  'CAIZRB01',
#  'CAIZSN01',
#  'CAIWUP01',
#  'CAIXBB01',
#  'CAIXKS01',
#  'CAIXKU01',
#  'CAIXLN01',
#  'CAIXOZ01',
#  'CAIYEC01',
#  'CAIYEE01',
#  'CAISKX01',
#  'CAISPN01',
#  'CAISRP01',
#  'CAISRT01',
#  'CAISRW01',
#  'CAISTM01',
#  'CAISWB01',
#  'CAISZF01',
#  'CAISZL01',
#  'CAITCA01',
#  'CAITFR01',
#  'CAITHH01',
#  'CAITND01',
#  'CAITOU01',
#  'CAITZL01',
#  'CAIUAQ01',
#  'CAIUCS01',
#  'CAIUMG01',
#  'CAIUQY01',
#  'CAIVAU01',
#  'CAIVFS01',
#  'CAJBJJ01',
#  'CAJBJR01',
#  'CAJBKJ01',
#  'CAJBMA01',
#  'CAJBPY01',
#  'CAJBUV01',
#  'CAJBWW01',
#  'CAJBXU01',
#  'CAJCBE01',
#  'CAJCBZ01',
#  'CAJCFH01',
#  'CAJCFS01',
#  'CAJCFV01',
#  'CAIZWK01',
#  'CAIZXA01',
#  'CAIZXO01',
#  'CAJAAI01',
#  'CAJABW01',
#  'CAJACU01',
#  'CAIO01',
#  'CAJAIC01',
#  'CAJAKH01',
#  'CAJAKO01',
#  'CAJAKS01',
#  'CAJALB01',
#  'CAJALZ01',
#  'CAJAQB01',
#  'CAIP01',
#  'CAJARI01',
#  'CAJATQ01',
#  'CAIL01',
#  'CAJATR01',
#  'CAJAVH01',
#  'CAJAYV01',
#  'CAJAZF01',
#  'CAJAZO01',
#  'CAJBFY01',
#  'CAINZT01',
#  'CAIOBR01',
#  'CAIOCZ01',
#  'CAIOGZ01',
#  'CAIOIS01',
#  'CAIOPL01',
#  'CAIM01',
#  'CAIOXF01',
#  'CAIOXZ01',
#  'CAIPDK01',
#  'CAIKZL01',
#  'CAILBA01',
#  'CAILFB01',
#  'CAILFC01',
#  'CAIK01',
#  'CAILHQ01',
#  'CAILIL01',
#  'CAILJR01',
#  'CAILLV01',
#  'CAILMH01',
#  'CAILTN01',
#  'CAILTU01',
#  'CAILUN01',
#  'CAILZV01',
#  'CAIMED01',
#  'CAIQ01',
#  'CAIMEM01',
#  'CAIJRN01',
#  'CAIJSG01',
#  'CAIJVB01',
#  'CAIJWW01',
#  'CAIJZP01',
#  'CAIKEC01',
#  'CAIKFC01',
#  'CAIKSK01',
#  'CAIKSR01',
#  'CAIKWV01',
#  'CAIN01',
#  'CAIPKM01',
#  'CAIPOC01',
#  'CAIPVN01',
#  'CAIPYC01',
#  'CAIPYS01',
#  'CAIQBV01',
#  'CAIQGS01',
#  'CAIQIA01',
#  'CAIQJE01',
#  'CAIQJY01',
#  'CAIQMA01',
#  'CAIQSI01',
#  'CAIQUF01',
#  'CAIMSC01',
#  'CAIMVL01',
#  'CAIMXA01',
#  'CAIS01',
#  'CAINAG01',
#  'CAINGU01',
#  'CAINPA01',
#  'CAIH01',
#  'CAINPH01',
#  'CAINPL01',
#  'CAINTH01',
#  'CAINUV01',
#  'CAII01',
#  'CAIJ01',
#  'CAINUW01',
#  'CAINWI01',
#  'CAINWT01',
#  'CAIQXI01',
#  'CAIRGI01',
#  'CAIRHH01',
#  'CAIRPA01',
#  'CAIRRO01',
#  'CAIRWM01',
#  'CAISAU01',
#  'CAISDG01',
#  'CBZS01',
#  'CAISIH01',
#  'CADCTM01',
#  'CADCTY01',
#  'CAQK01',
#  'CAQL01',
#  'CAQM01',
#  'CAQN01',
#  'CDHJ01',
#  'DLDG01',
#  'DLDQ01',
#  'DLEF01',
#  'DLEZ01',
#  'DLGM01',
#  'DLLM01',
#  'DLPW01',
#  'DLSU01',
#  'DLUV01',
#  'DLXW01',
#  'DLZW01',
#  'DMEQ01',
#  'DMJW01',
#  'CADCTZ01',
#  'CADCWO01',
#  'DVDT01',
#  'DVDU01',
#  'DVDV01',
#  'DVDW01',
#  'DVDX01',
#  'DVDY01',
#  'DVDZ01',
#  'DVEA01',
#  'DVEB01',
#  'DVEC01',
#  'DVED01',
#  'DVEE01',
#  'DVEF01',
#  'DPNP01',
#  'DPOG01',
#  'DQAX01',
#  'DQEB01',
#  'DOBT01',
#  'DOFR01',
#  'DOHO01',
#  'DOIX01',
#  'DOJB01',
#  'DOMQ01',
#  'DOPQ01',
#  'DOPZ01',
#  'DOQK01',
#  'DORF01',
#  'DORG01',
#  'DOVM01',
#  'DOVO01',
#  'DOWB01',
#  'DPEI01',
#  'DPLL01',
#  'DMPD01',
#  'DMPE01',
#  'DMPJ01',
#  'DMXX01',
#  'DMYK01',
#  'DNGG01',
#  'DNGI01',
#  'DNGJ01',
#  'DNLA01',
#  'DNME01',
#  'DNOV01',
#  'DNOW01',
#  'DNOY01',
#  'DNOZ01',
#  'DNRP01',
#  'DNSU01',
#  'DNUG01',
#  'DNXU01',
#  'DNYC01',
#  'DNYD01',
#  'DNYY01',
#  'DNZA01',
#  'DVEG01',
#  'DVEH01',
#  'DYNF01',
#  'DSGY01',
#  'DSMC01',
#  'DSPK01',
#  'DSPW01',
#  'DSPX01',
#  'DSQC01',
#  'DBAX01',
#  'DBCX01',
#  'DBIX01',
#  'DBVD01',
#  'DBVH01',
#  'DBXD01',
#  'DBYM01',
#  'DCNZ01',
#  'DCQC01',
#  'DCSN01',
#  'DDLS01',
#  'DFEL01',
#  'DFQU01',
#  'DFRI01',
#  'DFVO01',
#  'DFYB01',
#  'DGBR01',
#  'DGDG01',
#  'DGDH01',
#  'DIYQ01',
#  'DIYT01',
#  'DDVE01',
#  'DEDY01',
#  'DEEH01',
#  'DEEN01',
#  'DEFJ01',
#  'DEGT01',
#  'DEGZ01',
#  'DESS01',
#  'DESZ01',
#  'DJOE01',
#  'DJQF01',
#  'DJYG01',
#  'DJYZ01',
#  'DKMR01',
#  'DKOB01',
#  'DKOE01',
#  'DKRT01',
#  'DGYA01',
#  'DHMN01',
#  'DSRD01',
#  'DSRU01',
#  'CAIJEA01',
#  'CAIJFA01',
#  'CAIJJB01',
#  'CAJXSQ01',
#  'CAJXVH01',
#  'CAJWKD01',
#  'ASSJ01',
#  'CAJWNL01',
#  'ASZQ01',
#  'CAJWON01',
#  'ATDS01',
#  'CAJWSD01',
#  'CAJWUF01',
#  'BLJI01',
#  'BLZO01',
#  'JAABOT01',
#  'JAABRE01',
#  'BOWF01',
#  'BOXC01',
#  'BOXD01',
#  'BOYO01',
#  'AUMZ01',
#  'AUNA01',
#  'AUSW01',
#  'AUZM01',
#  'AVFS01',
#  'ARCP01',
#  'BOYP01',
#  'AVFT01',
#  'AVFU01',
#  'AVFV01',
#  'BPAC01',
#  'AVFW01',
#  'AVFX01',
#  'AVFY01',
#  'AVFZ01',
#  'AWNH01',
#  'FITM01',
#  'FXBO01',
#  'FXWN01',
#  'FYBH01',
#  'JENA01',
#  'JHEG04',
#  'UCNL01',
#  'UCNM01',
#  'JJML01',
#  'AXAQ01',
#  'JMIX01',
#  'JNAG01',
#  'JNAH01',
#  'JNAI01',
#  'JNAJ01',
#  'JNAK01',
#  'JNAL01',
#  'JNAM01',
#  'JNAN01',
#  'FSSI02',
#  'JNAO01',
#  'JNAP01',
#  'JAABRK01',
#  'JAABRM01',
#  'JAABSD01',
#  'JAABSJ01',
#  'JAABST01',
#  'JAABSU01',
#  'JAACDE01',
#  'JAACPM01',
#  'JAACQX01',
#  'JAACSJ01',
#  'JAACTD01',
#  'JAACUG01',
#  'CAJWVT01',
#  'CAACVJ01',
#  'JAAORC01',
#  'JAAORD01',
#  'JAAORE01',
#  ...]

# %%
if os.path.exists("./wgs_selector_211125.csv"):
    missing_genomes = []
    with open("./ids_211125.txt") as ids:
        Lines = ids.readlines()
        for line in Lines:
            if 'NZ_' in line:
                prefix = line.split(",")[0]
                prefix = prefix[3:]
            else:
                prefix = line.split(",")[0]
            if prefix not in downloaded_list:
                missing_genomes.append(prefix)

# %%
missing_genomes
# Out:
# []

# %% [markdown]
# ## Running MASH

# %%
# !ls /Volumes/TFL210426/schneider/fasta_genomes/*.fasta | wc -l
# Out:
#     3400

# %% [markdown]
# https://github.com/marbl/Mash/releases

# %%
start_time = time.time()

if os.path.exists("./mash-OSX64-v2.3/ncbi_genomes_3.msh"):
    print("Sketch already exists")
else:
    subprocess.call("./mash-OSX64-v2.3/mash sketch -o ./mash-OSX64-v2.3/ncbi_genomes_3 /Volumes/TFL210426/schneider/fasta_genomes/*.fasta",shell=True)
    
print('\n' + "--- %s seconds ---" %(time.time()-start_time))
# Out:
# --- 1037.9838089942932 seconds ---

# %%
def run_mash_df(fasta_input,sketch):
    start_time = time.time()
    cmd = "./mash-OSX64-v2.3/mash dist %s %s > ./mash-OSX64-v2.3/mash_df_3.txt"%(sketch,fasta_input)
    subprocess.call(cmd,shell=True)
    print('\n' + "--- %s seconds ---" %(time.time()-start_time))
        
run_mash_df("./CENA71.fasta","./mash-OSX64-v2.3/ncbi_genomes_3.msh")
# Out:
# --- 0.7175679206848145 seconds ---

# %%
mash_df = pd.read_csv("./mash-OSX64-v2.3/mash_df_3.txt",sep="\t",names=["reference","query","distance","pvalue","matching-hashes"])

mash_df = mash_df.sort_values(by=['distance'])

mash_df[:20]
# Out:
#                                               reference           query  \
# 29    /Volumes/TFL210426/schneider/fasta_genomes/AJL...  ./CENA71.fasta
# 62    /Volumes/TFL210426/schneider/fasta_genomes/ALV...  ./CENA71.fasta
# 2197  /Volumes/TFL210426/schneider/fasta_genomes/LIR...  ./CENA71.fasta
# 67    /Volumes/TFL210426/schneider/fasta_genomes/ALV...  ./CENA71.fasta
# 2268  /Volumes/TFL210426/schneider/fasta_genomes/MNP...  ./CENA71.fasta
# 2321  /Volumes/TFL210426/schneider/fasta_genomes/NAP...  ./CENA71.fasta
# 3086  /Volumes/TFL210426/schneider/fasta_genomes/QLK...  ./CENA71.fasta
# 1959  /Volumes/TFL210426/schneider/fasta_genomes/JAH...  ./CENA71.fasta
# 30    /Volumes/TFL210426/schneider/fasta_genomes/AJL...  ./CENA71.fasta
# 2404  /Volumes/TFL210426/schneider/fasta_genomes/NRQ...  ./CENA71.fasta
# 1378  /Volumes/TFL210426/schneider/fasta_genomes/JAC...  ./CENA71.fasta
# 2377  /Volumes/TFL210426/schneider/fasta_genomes/NMQ...  ./CENA71.fasta
# 2375  /Volumes/TFL210426/schneider/fasta_genomes/NMQ...  ./CENA71.fasta
# 2383  /Volumes/TFL210426/schneider/fasta_genomes/NMQ...  ./CENA71.fasta
# 2382  /Volumes/TFL210426/schneider/fasta_genomes/NMQ...  ./CENA71.fasta
# 2333  /Volumes/TFL210426/schneider/fasta_genomes/NGZ...  ./CENA71.fasta
# 2341  /Volumes/TFL210426/schneider/fasta_genomes/NHA...  ./CENA71.fasta
# 26    /Volumes/TFL210426/schneider/fasta_genomes/AGI...  ./CENA71.fasta
# 2346  /Volumes/TFL210426/schneider/fasta_genomes/NHA...  ./CENA71.fasta
# 2347  /Volumes/TFL210426/schneider/fasta_genomes/NHA...  ./CENA71.fasta
#
#       distance         pvalue matching-hashes
# 29    0.074070   0.000000e+00        118/1000
# 62    0.079484   0.000000e+00        104/1000
# 2197  0.079901   0.000000e+00        103/1000
# 67    0.079901   0.000000e+00        103/1000
# 2268  0.081614   0.000000e+00         99/1000
# 2321  0.082054   0.000000e+00         98/1000
# 3086  0.083404   0.000000e+00         95/1000
# 1959  0.086249   0.000000e+00         89/1000
# 30    0.126974  9.205260e-154         36/1000
# 2404  0.126974  6.184730e-154         36/1000
# 1378  0.126974  9.383780e-154         36/1000
# 2377  0.132399  5.367040e-136         32/1000
# 2375  0.133864  1.703880e-132         31/1000
# 2383  0.133864  8.864640e-131         31/1000
# 2382  0.133864  2.594440e-131         31/1000
# 2333  0.135380  7.472280e-128         30/1000
# 2341  0.136948  3.053810e-123         29/1000
# 26    0.136948  3.789730e-123         29/1000
# 2346  0.136948  3.666160e-123         29/1000
# 2347  0.136948  2.984100e-123         29/1000

# %% [markdown]
# ## Polishing the dataframe

# %%
from Bio import SeqIO

def split_string_at(s, c, n):
    words = s.split(c)
    return c.join(words[:n]), c.join(words[n:])

def extract_ncbi_taxa(inputs_folder):
    input_list = glob.glob("%s*.fasta"%inputs_folder)
    taxa = {}
    for item in input_list:
        records = list(SeqIO.parse(item, "fasta"))
        strain = os.path.splitext(os.path.basename(item))[0]
        if records:
            if "TPA_asm" in str(records[0]):
                genera = split_string_at(genera,":",1)[0]
            else:
                genera = split_string_at(records[0].description," ",1)[1]
            if "Candidatus" in str(genera):
                taxa[strain] = str(genera).partition(' ')[2].partition(' ')[0]
            else:
                taxa[strain] = str(genera).partition(' ')[0].lstrip("[").rstrip("]")
    return taxa
            
taxa_dict = extract_ncbi_taxa("/Volumes/TFL210426/schneider/fasta_genomes/")

# %%
taxa_dict
# Out:
# {'AADV02': 'Crocosphaera',
#  'WJFC01': 'Scytonema',
#  'WGLZ01': 'Cyanobacteria',
#  'WGNO01': 'Nostoc',
#  'WBKL01': 'Nostoc',
#  'WBKM01': 'Nostoc',
#  'WBKN01': 'Nostoc',
#  'WLWJ01': 'Synechococcus',
#  'WMIA01': 'Cyanobacterium',
#  'WTFZ01': 'Synechococcus',
#  'WTGE01': 'Synechococcus',
#  'WTHF01': 'Synechococcus',
#  'WTHL01': 'Synechococcus',
#  'WTKN01': 'MAG:',
#  'WVIC01': 'Synechococcales',
#  'WVID01': 'Nostoc',
#  'WVIE01': 'Myxacorys',
#  'JACAEU01': 'Fischerella',
#  'JACJRZ01': 'Fischerella',
#  'JACYLX01': 'Fischerella',
#  'JACYLY01': 'Fischerella',
#  'JACYMA01': 'Fischerella',
#  'CABUCV01': 'Fischerella',
#  'CABXTM01': 'uncultured',
#  'CABSEX01': 'uncultured',
#  'CABXSG01': 'uncultured',
#  'CABXUT01': 'uncultured',
#  'CABXYB01': 'uncultured',
#  'CABUXD01': 'uncultured',
#  'CABYAP01': 'uncultured',
#  'CABYAW01': 'uncultured',
#  'CABYEB01': 'uncultured',
#  'CABYEL01': 'uncultured',
#  'CABYGI01': 'uncultured',
#  'CABYIY01': 'uncultured',
#  'CABYJE01': 'uncultured',
#  'CABYJI01': 'uncultured',
#  'CABYKM01': 'uncultured',
#  'CABYKV01': 'uncultured',
#  'CABYLC01': 'uncultured',
#  'CABYLJ01': 'uncultured',
#  'CABYLR01': 'uncultured',
#  'CABYMM01': 'uncultured',
#  'CABYNM01': 'uncultured',
#  'CABYNZ01': 'uncultured',
#  'CABYPO01': 'uncultured',
#  'CABYPR01': 'uncultured',
#  'CABYQF01': 'uncultured',
#  'CABYQY01': 'uncultured',
#  'CABYRK01': 'uncultured',
#  'CABYRO01': 'uncultured',
#  'CABYRZ01': 'uncultured',
#  'CABYSR01': 'uncultured',
#  'CABYTO01': 'uncultured',
#  'CABYTR01': 'uncultured',
#  'CABYUE01': 'uncultured',
#  'CABYWN01': 'uncultured',
#  'CABYWR01': 'uncultured',
#  'CABYWZ01': 'uncultured',
#  'CABYXI01': 'uncultured',
#  'CABYYN01': 'uncultured',
#  'CABYZN01': 'uncultured',
#  'CABZBE01': 'uncultured',
#  'CACA01': 'Oscillatoria',
#  'CABZBP01': 'uncultured',
#  'CABZCY01': 'uncultured',
#  'CABZEQ01': 'uncultured',
#  'CABZFE01': 'uncultured',
#  'CABZFV01': 'uncultured',
#  'CABZFW01': 'uncultured',
#  'CABZHQ01': 'uncultured',
#  'CABZJH01': 'uncultured',
#  'CABZJX01': 'uncultured',
#  'CABZLA01': 'uncultured',
#  'CABZNT01': 'uncultured',
#  'CABZOU01': 'uncultured',
#  'CABZPX01': 'uncultured',
#  'CABZQQ01': 'uncultured',
#  'CABZRB01': 'uncultured',
#  'CABZRX01': 'uncultured',
#  'CACAFA01': 'uncultured',
#  'CACAIX01': 'uncultured',
#  'CACAKA01': 'uncultured',
#  'CACAKJ01': 'uncultured',
#  'CACAMT01': 'uncultured',
#  'CACANT01': 'uncultured',
#  'CACAQA01': 'uncultured',
#  'CACAQD01': 'uncultured',
#  'CACAQF01': 'uncultured',
#  'CACAQP01': 'uncultured',
#  'CACAQQ01': 'uncultured',
#  'CACARF01': 'uncultured',
#  'CACARV01': 'uncultured',
#  'CACASR01': 'uncultured',
#  'CACAST01': 'uncultured',
#  'CACATM01': 'uncultured',
#  'CACATU01': 'uncultured',
#  'CACATZ01': 'uncultured',
#  'CACAUG01': 'uncultured',
#  'CACAVZ01': 'uncultured',
#  'CACAWW01': 'uncultured',
#  'CACAXN01': 'uncultured',
#  'CACAXR01': 'uncultured',
#  'CACAXS01': 'uncultured',
#  'CACAYO01': 'uncultured',
#  'CACAYX01': 'uncultured',
#  'CACAZF01': 'uncultured',
#  'CACBAW01': 'uncultured',
#  'CACBBE01': 'uncultured',
#  'CACBBH01': 'uncultured',
#  'CACBBI01': 'uncultured',
#  'CACBBJ01': 'uncultured',
#  'CACBCR01': 'uncultured',
#  'CACBDL01': 'uncultured',
#  'CACBDN01': 'uncultured',
#  'CACBEF01': 'uncultured',
#  'CACBES01': 'uncultured',
#  'CACBFH01': 'uncultured',
#  'CACBGC01': 'uncultured',
#  'CACBGI01': 'uncultured',
#  'CACBHP01': 'uncultured',
#  'CACBIT01': 'uncultured',
#  'CACBJB01': 'uncultured',
#  'CACBKH01': 'uncultured',
#  'CACBKT01': 'uncultured',
#  'CACBOC01': 'uncultured',
#  'CACBOU01': 'uncultured',
#  'CACBRO01': 'uncultured',
#  'CACBRZ01': 'uncultured',
#  'CACBSA01': 'uncultured',
#  'CACBSY01': 'uncultured',
#  'CACBTG01': 'uncultured',
#  'CACBTP01': 'uncultured',
#  'CACBTY01': 'uncultured',
#  'CACBVE01': 'uncultured',
#  'CACBVY01': 'uncultured',
#  'CACBYI01': 'uncultured',
#  'CACDRN01': 'uncultured',
#  'CACEAF01': 'uncultured',
#  'CACEAS01': 'uncultured',
#  'CACEEF01': 'uncultured',
#  'CACEFS01': 'uncultured',
#  'CACEHU01': 'uncultured',
#  'CACEMU01': 'uncultured',
#  'CACENO01': 'uncultured',
#  'CACEPA01': 'uncultured',
#  'CACEPC01': 'uncultured',
#  'CACEPF01': 'uncultured',
#  'CACEPP01': 'uncultured',
#  'CACEPZ01': 'uncultured',
#  'CACEQI01': 'uncultured',
#  'AANP01': 'Synechococcus',
#  'CACEVR01': 'uncultured',
#  'CACEWU01': 'uncultured',
#  'CACCCI01': 'uncultured',
#  'CACCGY01': 'uncultured',
#  'CACCHB01': 'uncultured',
#  'CACCIG01': 'uncultured',
#  'CACCKF01': 'uncultured',
#  'CACCKP01': 'uncultured',
#  'CACCSS01': 'uncultured',
#  'CACCWM01': 'uncultured',
#  'CACCZQ01': 'uncultured',
#  'CACDDK01': 'uncultured',
#  'CACDDW01': 'uncultured',
#  'CACDFY01': 'uncultured',
#  'CACDIE01': 'uncultured',
#  'CACDJL01': 'uncultured',
#  'CACJKR01': 'uncultured',
#  'CACJNU01': 'uncultured',
#  'CACJOV01': 'uncultured',
#  'CACJOW01': 'uncultured',
#  'CACJOZ01': 'uncultured',
#  'CACJPB01': 'uncultured',
#  'CACJQY01': 'uncultured',
#  'CACJSF01': 'uncultured',
#  'CACJTA01': 'uncultured',
#  'CACJTI01': 'uncultured',
#  'CACJUL01': 'uncultured',
#  'CACJVD01': 'uncultured',
#  'CACJVV01': 'uncultured',
#  'CACJWO01': 'uncultured',
#  'CACJYM01': 'uncultured',
#  'CACJYO01': 'uncultured',
#  'CACJZI01': 'uncultured',
#  'CACKAH01': 'uncultured',
#  'CACKBB01': 'uncultured',
#  'CACKBW01': 'uncultured',
#  'CACKEF01': 'uncultured',
#  'CACKEW01': 'uncultured',
#  'CACKFN01': 'uncultured',
#  'CACKFR01': 'uncultured',
#  'CACKFT01': 'uncultured',
#  'CACKGR01': 'uncultured',
#  'CACKHE01': 'uncultured',
#  'CACKHG01': 'uncultured',
#  'CACKHU01': 'uncultured',
#  'CACKIA01': 'uncultured',
#  'CACKIP01': 'uncultured',
#  'CACKIV01': 'uncultured',
#  'CACKJA01': 'uncultured',
#  'CACKJL01': 'uncultured',
#  'CACKJM01': 'uncultured',
#  'CACKKG01': 'uncultured',
#  'CACKKJ01': 'uncultured',
#  'CACKLP01': 'uncultured',
#  'CACKMQ01': 'uncultured',
#  'CACKMT01': 'uncultured',
#  'CACKOL01': 'uncultured',
#  'CACKPW01': 'uncultured',
#  'CACKQL01': 'uncultured',
#  'CACKSS01': 'uncultured',
#  'CACKUC01': 'uncultured',
#  'CACKUH01': 'uncultured',
#  'CACKUU01': 'uncultured',
#  'CACKWB01': 'uncultured',
#  'CACHYK01': 'uncultured',
#  'CACHYR01': 'uncultured',
#  'CACHZW01': 'uncultured',
#  'CACIAM01': 'uncultured',
#  'CACIBI01': 'uncultured',
#  'CACIBL01': 'uncultured',
#  'CACIGP01': 'uncultured',
#  'CACIIM01': 'uncultured',
#  'CACIIQ01': 'uncultured',
#  'CACILY01': 'uncultured',
#  'CACINK01': 'uncultured',
#  'CACINL01': 'uncultured',
#  'CACINM01': 'uncultured',
#  'CACIRS01': 'uncultured',
#  'CACITH01': 'uncultured',
#  'CACIUY01': 'uncultured',
#  'CACIVI01': 'uncultured',
#  'CACIWI01': 'uncultured',
#  'CACIYC01': 'uncultured',
#  'CACIYG01': 'uncultured',
#  'CACJAC01': 'uncultured',
#  'CACJBP01': 'uncultured',
#  'CACJCK01': 'uncultured',
#  'CACJDX01': 'uncultured',
#  'CACJEA01': 'uncultured',
#  'CACJFG01': 'uncultured',
#  'CACJFL01': 'uncultured',
#  'CACJJC01': 'uncultured',
#  'CACKZL01': 'uncultured',
#  'CACKZX01': 'uncultured',
#  'CACKZZ01': 'uncultured',
#  'CACLAH01': 'uncultured',
#  'CACLAV01': 'uncultured',
#  'CACLBR01': 'uncultured',
#  'CACLBT01': 'uncultured',
#  'CACLCE01': 'uncultured',
#  'CACLCP01': 'uncultured',
#  'CACLCS01': 'uncultured',
#  'CACLDO01': 'uncultured',
#  'CACLET01': 'uncultured',
#  'CACLFP01': 'uncultured',
#  'CACLFQ01': 'uncultured',
#  'CACLGH01': 'uncultured',
#  'CACLGP01': 'uncultured',
#  'CACLGR01': 'uncultured',
#  'CACLGU01': 'uncultured',
#  'CACLPH01': 'uncultured',
#  'CACLPT01': 'uncultured',
#  'CACLQL01': 'uncultured',
#  'CACLQU01': 'uncultured',
#  'CACLRA01': 'uncultured',
#  'CACLRT01': 'uncultured',
#  'CACLTA01': 'uncultured',
#  'CACLUB01': 'uncultured',
#  'CACLUD01': 'uncultured',
#  'CACLUE01': 'uncultured',
#  'CACLWO01': 'uncultured',
#  'CACLXQ01': 'uncultured',
#  'CACLYB01': 'uncultured',
#  'CACLYD01': 'uncultured',
#  'CACLYT01': 'uncultured',
#  'CACLYZ01': 'uncultured',
#  'CACMAP01': 'uncultured',
#  'CACMAV01': 'uncultured',
#  'CACMBG01': 'uncultured',
#  'CACMCA01': 'uncultured',
#  'CACMDI01': 'uncultured',
#  'CACMDN01': 'uncultured',
#  'CACMDV01': 'uncultured',
#  'CACMJF01': 'uncultured',
#  'CACMKY01': 'uncultured',
#  'CACMLG01': 'uncultured',
#  'CACMLO01': 'uncultured',
#  'CACMNZ01': 'uncultured',
#  'CACMOD01': 'uncultured',
#  'CACMQW01': 'uncultured',
#  'CACMRI01': 'uncultured',
#  'CACMSA01': 'uncultured',
#  'CACMSM01': 'uncultured',
#  'CACMTC01': 'uncultured',
#  'CACMTE01': 'uncultured',
#  'CACMTJ01': 'uncultured',
#  'CACMTS01': 'uncultured',
#  'CACMUV01': 'uncultured',
#  'CACMXO01': 'uncultured',
#  'CACMYI01': 'uncultured',
#  'CACMZV01': 'uncultured',
#  'CACNAG01': 'uncultured',
#  'CACNAI01': 'uncultured',
#  'CACNAS01': 'uncultured',
#  'CACNCC01': 'uncultured',
#  'CACNCF01': 'uncultured',
#  'CACNDQ01': 'uncultured',
#  'CACNEE01': 'uncultured',
#  'CACNFQ01': 'uncultured',
#  'CACNFR01': 'uncultured',
#  'CACNGR01': 'uncultured',
#  'CACNJU01': 'uncultured',
#  'CACNJX01': 'uncultured',
#  'CACNMD01': 'uncultured',
#  'CACNMF01': 'uncultured',
#  'CACNMX01': 'uncultured',
#  'CACNNF01': 'uncultured',
#  'CACNPL01': 'uncultured',
#  'CACNQB01': 'uncultured',
#  'CACNQI01': 'uncultured',
#  'CACNQS01': 'uncultured',
#  'CACNQT01': 'uncultured',
#  'CACNSB01': 'uncultured',
#  'CACNSF01': 'uncultured',
#  'CACNSG01': 'uncultured',
#  'CACNSV01': 'uncultured',
#  'CACNUB01': 'uncultured',
#  'CACNUL01': 'uncultured',
#  'CACGMX01': 'uncultured',
#  'CACGNA01': 'uncultured',
#  'CACGNH01': 'uncultured',
#  'CACGNS01': 'uncultured',
#  'CACGOG01': 'uncultured',
#  'CACGPQ01': 'uncultured',
#  'CACGRX01': 'uncultured',
#  'CACGSV01': 'uncultured',
#  'CACGTI01': 'uncultured',
#  'CACGVZ01': 'uncultured',
#  'CACHAH01': 'uncultured',
#  'CACHDC01': 'uncultured',
#  'CACHDE01': 'uncultured',
#  'CACHDL01': 'uncultured',
#  'CACHEM01': 'uncultured',
#  'CACHGL01': 'uncultured',
#  'CACHGM01': 'uncultured',
#  'CACHJG01': 'uncultured',
#  'CACHKB01': 'uncultured',
#  'CACHMM01': 'uncultured',
#  'CACHMO01': 'uncultured',
#  'CACHMR01': 'uncultured',
#  'CACHNH01': 'uncultured',
#  'CACHPH01': 'uncultured',
#  'CACHQH01': 'uncultured',
#  'CACHQJ01': 'uncultured',
#  'CACHRC01': 'uncultured',
#  'CACHRD01': 'uncultured',
#  'CACHSO01': 'uncultured',
#  'CACHST01': 'uncultured',
#  'CACHTY01': 'uncultured',
#  'CACHUE01': 'uncultured',
#  'CACHUM01': 'uncultured',
#  'CACHUV01': 'uncultured',
#  'CACHVD01': 'uncultured',
#  'CACHVU01': 'uncultured',
#  'CACHXJ01': 'uncultured',
#  'CACHXS01': 'uncultured',
#  'CACHXX01': 'uncultured',
#  'CACEZU01': 'uncultured',
#  'CACFAG01': 'uncultured',
#  'CACFAJ01': 'uncultured',
#  'CACFBG01': 'uncultured',
#  'CACFCB01': 'uncultured',
#  'CACFDU01': 'uncultured',
#  'CACFEJ01': 'uncultured',
#  'CACFFG01': 'uncultured',
#  'CACFHT01': 'uncultured',
#  'CACFLN01': 'uncultured',
#  'CACFMC01': 'uncultured',
#  'CACFRT01': 'uncultured',
#  'CACFSS01': 'uncultured',
#  'CACFWF01': 'uncultured',
#  'CACFYM01': 'uncultured',
#  'CACFZG01': 'uncultured',
#  'CACGAJ01': 'uncultured',
#  'CACGAP01': 'uncultured',
#  'CACGAY01': 'uncultured',
#  'CACGBL01': 'uncultured',
#  'CACGBQ01': 'uncultured',
#  'CACGBT01': 'uncultured',
#  'CACGCE01': 'uncultured',
#  'CACGCM01': 'uncultured',
#  'CACGCN01': 'uncultured',
#  'CACGDL01': 'uncultured',
#  'CACGEL01': 'uncultured',
#  'CACGER01': 'uncultured',
#  'CACGFD01': 'uncultured',
#  'CACGFK01': 'uncultured',
#  'CACGFP01': 'uncultured',
#  'CACGFX01': 'uncultured',
#  'CACGGL01': 'uncultured',
#  'CACGGY01': 'uncultured',
#  'CACGHD01': 'uncultured',
#  'CACGHI01': 'uncultured',
#  'CACGHM01': 'uncultured',
#  'CACGHR01': 'uncultured',
#  'CACGIB01': 'uncultured',
#  'CACGIK01': 'uncultured',
#  'CACGJI01': 'uncultured',
#  'CACGJP01': 'uncultured',
#  'CACGKI01': 'uncultured',
#  'CACGKN01': 'uncultured',
#  'CACGKT01': 'uncultured',
#  'CACGLB01': 'uncultured',
#  'CACNVU01': 'uncultured',
#  'CACNWD01': 'uncultured',
#  'CACNWG01': 'uncultured',
#  'CACNWH01': 'uncultured',
#  'CACNYU01': 'uncultured',
#  'CACOAG01': 'uncultured',
#  'CACOAN01': 'uncultured',
#  'CACOAY01': 'uncultured',
#  'CACOBU01': 'uncultured',
#  'CACOCO01': 'uncultured',
#  'CACOCT01': 'uncultured',
#  'CACOER01': 'uncultured',
#  'CACOEX01': 'uncultured',
#  'CACOFD01': 'uncultured',
#  'CACOFK01': 'uncultured',
#  'CACOFO01': 'uncultured',
#  'CACOFR01': 'uncultured',
#  'CACOHO01': 'uncultured',
#  'CACOIJ01': 'uncultured',
#  'CACOIM01': 'uncultured',
#  'CACOIV01': 'uncultured',
#  'AAZV01': 'Leptolyngbya',
#  'CACOIW01': 'uncultured',
#  'ABRS01': 'Coleofasciculus',
#  'ABRV01': 'Synechococcus',
#  'ABSE01': 'Cyanobium',
#  'ABYK01': 'Limnospira',
#  'ACDW01': 'Prochlorococcus',
#  'ACSK03': 'Arthrospira',
#  'AFXD01': 'Arthrospira',
#  'AGCR01': 'Tolypothrix',
#  'AGIK01': 'Synechococcus',
#  'AGIZ01': 'Fischerella',
#  'AEPQ01': 'Moorena',
#  'AESD01': 'Crocosphaera',
#  'AFEJ01': 'Acaryochloris',
#  'AFJC01': 'Microcoleus',
#  'ACYA01': 'Cylindrospermopsis',
#  'ACYB01': 'Raphidiopsis',
#  'ADXM01': 'Synechococcus',
#  'ALPB01': 'Prochlorococcus',
#  'ALPC01': 'Prochlorococcus',
#  'ALPD01': 'Prochlorococcus',
#  'ALPE01': 'Prochlorococcus',
#  'ALPF01': 'Prochlorococcus',
#  'ALPG01': 'Prochlorococcus',
#  'ALPH01': 'Prochlorococcus',
#  'ALPI01': 'Prochlorococcus',
#  'ALPJ01': 'Prochlorococcus',
#  'ALPK01': 'Prochlorococcus',
#  'ALPL01': 'Prochlorococcus',
#  'ALVI01': 'Kamptonema',
#  'ALVJ01': 'Calothrix',
#  'ALVK01': 'Pseudanabaena',
#  'ALVL01': 'Pleurocapsa',
#  'ALVM01': 'Leptolyngbya',
#  'ALVN01': 'Leptolyngbya',
#  'ALVO01': 'Geminocystis',
#  'ALVP01': 'Nodosilinea',
#  'ALVQ01': 'Spirulina',
#  'ALVR01': 'Spirulina',
#  'ALVS01': 'Fischerella',
#  'ALVT01': 'Fischerella',
#  'ALVU02': 'Synechocystis',
#  'ALVV02': 'Leptolyngbya',
#  'ALVW01': 'Mastigocladopsis',
#  'ALVX01': 'Fischerella',
#  'ALVY01': 'Gloeocapsa',
#  'ALVZ01': 'Xenococcus',
#  'ALWA01': 'Cyanobacterium',
#  'ALWB01': 'Pseudanabaena',
#  'ALWC01': 'Synechococcus',
#  'ALWD01': 'Scytonema',
#  'AHGV01': 'Thermanaerovibrio',
#  'AJTX02': 'Prochlorothrix',
#  'AJUB01': 'Leptolyngbyaceae',
#  'AJUS01': 'Microcystis',
#  'AJUT01': 'Microcystis',
#  'AJUU01': 'Microcystis',
#  'AJWF01': 'Anabaena',
#  'AJYB01': 'Planococcus',
#  'AJHB01': 'Microcystis',
#  'AJLJ01': 'Fischerella',
#  'AJLK01': 'Fischerella',
#  'AJLL01': 'Fischerella',
#  'AJLM01': 'Chlorogloeopsis',
#  'AJLN01': 'Chlorogloeopsis',
#  'AZXL01': 'Synechococcus',
#  'AZYY01': 'Aphanizomenon',
#  'AXUV01': 'Synechococcus',
#  'AXUW01': 'Synechococcus',
#  'AXUX01': 'Synechococcus',
#  'AXZO01': 'Synechococcus',
#  'BDGE01': 'Nostoc',
#  'BDQK01': 'Aphanothece',
#  'BDQL01': 'Aphanothece',
#  'BDSG01': 'Microcystis',
#  'BDSM01': 'Microcystis',
#  'BDUB01': 'Nodularia',
#  'BDUC01': 'Tolypothrix',
#  'BDUD01': 'Nostoc',
#  'BAUB01': 'Synechococcus',
#  'BAWS01': 'Synechococcus',
#  'CACOIZ01': 'uncultured',
#  'BBPA01': 'Microcystis',
#  'BBWW01': 'Leptolyngbya',
#  'CACOMD01': 'uncultured',
#  'BBJB01': 'Pseudanabaena',
#  'BJCD01': 'Planktothrix',
#  'BJCE01': 'Sphaerospermopsis',
#  'BJCF01': 'Dolichospermum',
#  'BIMP01': 'Cyanobiont',
#  'BIMW01': 'Arthrospira',
#  'BJCH01': 'Microcystis',
#  'BJCI01': 'Microcystis',
#  'BJCJ01': 'Microcystis',
#  'BJCK01': 'Microcystis',
#  'BJHC01': 'Cyanobium',
#  'BJHD01': 'Cyanobium',
#  'BJHE01': 'Cyanobium',
#  'BEIU01': 'Microcystis',
#  'BEIV01': 'Microcystis',
#  'BEYQ01': 'Microcystis',
#  'BFAC01': 'Microcystis',
#  'BJKP01': 'Microcystis',
#  'CACOPF01': 'uncultured',
#  'BHVO01': 'Microcystis',
#  'BHVP01': 'Microcystis',
#  'BHVQ01': 'Microcystis',
#  'BHVR01': 'Microcystis',
#  'BIFY01': 'Microcystis',
#  'BHVS01': 'Microcystis',
#  'AANO01': 'Synechococcus',
#  'AAOK01': 'Synechococcus',
#  'BHVU01': 'Microcystis',
#  'CZCT02': 'Planktothrix',
#  'CACOQT01': 'uncultured',
#  'CZCS02': 'Planktothrix',
#  'CZDF01': 'Planktothrix',
#  'CVSV01': 'Prochlorococcus',
#  'CVSW01': 'Prochlorococcus',
#  'CVSX01': 'Prochlorococcus',
#  'CVSY01': 'Prochlorococcus',
#  'CVSZ01': 'Prochlorococcus',
#  'CZCU02': 'Planktothrix',
#  'CZCZ02': 'Planktothrix',
#  'CACOXH01': 'uncultured',
#  'CACOYJ01': 'uncultured',
#  'CACPBT01': 'uncultured',
#  'CACPFL01': 'uncultured',
#  'CACPHQ01': 'uncultured',
#  'CACPIH01': 'uncultured',
#  'CACPJY01': 'uncultured',
#  'CACPKH01': 'uncultured',
#  'CACPLK01': 'uncultured',
#  'CACPNN01': 'uncultured',
#  'CACPNZ01': 'uncultured',
#  'CABQEX01': 'uncultured',
#  'BLAY01': 'Microseira',
#  'CACVCJ01': 'uncultured',
#  'CAJQOK01': 'uncultured',
#  'CAJQPG01': 'uncultured',
#  'CAJQPQ01': 'uncultured',
#  'CAJGYW01': 'Psychrobacter',
#  'CAJHBF01': 'Psychrobacter',
#  'CAJHBU01': 'Psychrobacter',
#  'CAJWHY01': 'Psychrobacter',
#  'AATZ01': 'Synechococcus',
#  'BPQA01': 'Rivularia',
#  'AAUA01': 'Synechococcus',
#  'CAJWLE01': 'Synechococcus',
#  'CABUXT01': 'Synechococcus',
#  'AAVU01': 'Lyngbya',
#  'AAVW01': 'Nodularia',
#  'CAJWTR01': 'Nodularia',
#  'CABXCX01': 'uncultured',
#  'CAJWAH01': 'uncultured',
#  'AAXW01': 'Crocosphaera',
#  'ANFJ01': 'Fortiea',
#  'ANFQ01': 'Baaleninema',
#  'ANKN01': 'Prochlorothrix',
#  'ANKO01': 'Oscillatoria',
#  'CAFN01': 'Arthrospira',
#  'ANKQ01': 'Microcystis',
#  'ANNX02': 'Scytonema',
#  'AOCI01': 'Microcystis',
#  'CAJWYF01': 'Microcystis',
#  'CAJWYY01': 'Microcystis',
#  'CAJWDD01': 'Microcystis',
#  'CAJWZW01': 'Microcystis',
#  'APIY01': 'Dolichospermum',
#  'CAJWDZ01': 'Dolichospermum',
#  'APIZ01': 'Dolichospermum',
#  'CAJWIC01': 'Dolichospermum',
#  'AQPY01': 'Microcystis',
#  'CAJWIZ01': 'Microcystis',
#  'ASAC01': 'Cyanobium',
#  'ASAK01': 'Planktothrix',
#  'CAIVJC01': 'uncultured',
#  'CAIVMB01': 'uncultured',
#  'CAIVMI01': 'uncultured',
#  'CAIVPT01': 'uncultured',
#  'CAIVSA01': 'uncultured',
#  'CAIVSM01': 'uncultured',
#  'CAIVTY01': 'uncultured',
#  'CAIVUW01': 'uncultured',
#  'CAIVVJ01': 'uncultured',
#  'CAIWDD01': 'uncultured',
#  'CAIWES01': 'uncultured',
#  'CAIWEU01': 'uncultured',
#  'CAIWHD01': 'uncultured',
#  'CAIWIR01': 'uncultured',
#  'CAIWKG01': 'uncultured',
#  'CAIWLC01': 'uncultured',
#  'CAIWNN01': 'uncultured',
#  'CAIWPA01': 'uncultured',
#  'CAIWSY01': 'uncultured',
#  'CAIYIN01': 'uncultured',
#  'CAIYJT01': 'uncultured',
#  'CAIYLM01': 'uncultured',
#  'CAIYRW01': 'uncultured',
#  'CAIYSK01': 'uncultured',
#  'CAIZCV01': 'uncultured',
#  'CAIZDC01': 'Synechococcus',
#  'CAIZIV01': 'Synechococcus',
#  'CAIZKS01': 'uncultured',
#  'CAIY01': 'Richelia',
#  'CAIZLY01': 'Synechococcus',
#  'CAIZNP01': 'uncultured',
#  'CAIZNS01': 'uncultured',
#  'CAIZOI01': 'Synechococcus',
#  'CAIZOZ01': 'uncultured',
#  'CAIZPV01': 'uncultured',
#  'CAIZQP01': 'uncultured',
#  'CAIZQU01': 'uncultured',
#  'CAIZRB01': 'uncultured',
#  'CAIZSN01': 'Synechococcus',
#  'CAIWUP01': 'uncultured',
#  'CAIXBB01': 'uncultured',
#  'CAIXKS01': 'uncultured',
#  'CAIXKU01': 'uncultured',
#  'CAIXLN01': 'uncultured',
#  'CAIXOZ01': 'uncultured',
#  'CAIYEC01': 'uncultured',
#  'CAIYEE01': 'uncultured',
#  'CAISKX01': 'uncultured',
#  'CAISPN01': 'uncultured',
#  'CAISRP01': 'uncultured',
#  'CAISRT01': 'uncultured',
#  'CAISRW01': 'Synechococcus',
#  'CAISTM01': 'uncultured',
#  'CAISWB01': 'uncultured',
#  'CAISZF01': 'uncultured',
#  'CAISZL01': 'uncultured',
#  'CAITCA01': 'uncultured',
#  'CAITFR01': 'uncultured',
#  'CAITHH01': 'uncultured',
#  'CAITND01': 'uncultured',
#  'CAITOU01': 'uncultured',
#  'CAITZL01': 'uncultured',
#  'CAIUAQ01': 'uncultured',
#  'CAIUCS01': 'uncultured',
#  'CAIUMG01': 'uncultured',
#  'CAIUQY01': 'uncultured',
#  'CAIVAU01': 'uncultured',
#  'CAIVFS01': 'uncultured',
#  'CAJBJJ01': 'Synechococcus',
#  'CAJBJR01': 'Synechococcus',
#  'CAJBKJ01': 'uncultured',
#  'CAJBMA01': 'Synechococcus',
#  'CAJBPY01': 'uncultured',
#  'CAJBUV01': 'Synechococcus',
#  'CAJBWW01': 'Synechococcus',
#  'CAJBXU01': 'Synechococcus',
#  'CAJCBE01': 'uncultured',
#  'CAJCBZ01': 'Synechococcus',
#  'CAJCFH01': 'uncultured',
#  'CAJCFS01': 'uncultured',
#  'CAJCFV01': 'Planktothrix',
#  'CAIZWK01': 'Synechococcus',
#  'CAIZXA01': 'Synechococcus',
#  'CAIZXO01': 'Synechococcus',
#  'CAJAAI01': 'Synechococcus',
#  'CAJABW01': 'uncultured',
#  'CAJACU01': 'Synechococcus',
#  'CAIO01': 'Microcystis',
#  'CAJAIC01': 'Synechococcus',
#  'CAJAKH01': 'Synechococcus',
#  'CAJAKO01': 'Synechococcus',
#  'CAJAKS01': 'Synechococcus',
#  'CAJALB01': 'Synechococcus',
#  'CAJALZ01': 'uncultured',
#  'CAJAQB01': 'Synechococcus',
#  'CAIP01': 'Microcystis',
#  'CAJARI01': 'Synechococcus',
#  'CAJATQ01': 'Synechococcus',
#  'CAIL01': 'Microcystis',
#  'CAJATR01': 'Synechococcus',
#  'CAJAVH01': 'uncultured',
#  'CAJAYV01': 'Synechococcus',
#  'CAJAZF01': 'Synechococcus',
#  'CAJAZO01': 'uncultured',
#  'CAJBFY01': 'uncultured',
#  'CAINZT01': 'uncultured',
#  'CAIOBR01': 'uncultured',
#  'CAIOCZ01': 'uncultured',
#  'CAIOGZ01': 'uncultured',
#  'CAIOIS01': 'Synechococcus',
#  'CAIOPL01': 'uncultured',
#  'CAIM01': 'Microcystis',
#  'CAIOXF01': 'uncultured',
#  'CAIOXZ01': 'uncultured',
#  'CAIPDK01': 'uncultured',
#  'CAIKZL01': 'uncultured',
#  'CAILBA01': 'uncultured',
#  'CAILFB01': 'uncultured',
#  'CAILFC01': 'uncultured',
#  'CAIK01': 'Microcystis',
#  'CAILHQ01': 'uncultured',
#  'CAILIL01': 'uncultured',
#  'CAILJR01': 'uncultured',
#  'CAILLV01': 'Synechococcus',
#  'CAILMH01': 'uncultured',
#  'CAILTN01': 'uncultured',
#  'CAILTU01': 'uncultured',
#  'CAILUN01': 'Synechococcus',
#  'CAILZV01': 'uncultured',
#  'CAIMED01': 'uncultured',
#  'CAIQ01': 'Microcystis',
#  'CAIMEM01': 'uncultured',
#  'CAIJRN01': 'uncultured',
#  'CAIJSG01': 'uncultured',
#  'CAIJVB01': 'uncultured',
#  'CAIJWW01': 'uncultured',
#  'CAIJZP01': 'uncultured',
#  'CAIKEC01': 'Synechococcus',
#  'CAIKFC01': 'uncultured',
#  'CAIKSK01': 'uncultured',
#  'CAIKSR01': 'uncultured',
#  'CAIKWV01': 'uncultured',
#  'CAIN01': 'Microcystis',
#  'CAIPKM01': 'uncultured',
#  'CAIPOC01': 'Synechococcus',
#  'CAIPVN01': 'uncultured',
#  'CAIPYC01': 'uncultured',
#  'CAIPYS01': 'uncultured',
#  'CAIQBV01': 'uncultured',
#  'CAIQGS01': 'uncultured',
#  'CAIQIA01': 'uncultured',
#  'CAIQJE01': 'uncultured',
#  'CAIQJY01': 'Synechococcus',
#  'CAIQMA01': 'Synechococcus',
#  'CAIQSI01': 'uncultured',
#  'CAIQUF01': 'uncultured',
#  'CAIMSC01': 'uncultured',
#  'CAIMVL01': 'uncultured',
#  'CAIMXA01': 'uncultured',
#  'CAIS01': 'Richelia',
#  'CAINAG01': 'uncultured',
#  'CAINGU01': 'uncultured',
#  'CAINPA01': 'uncultured',
#  'CAIH01': 'Microcystis',
#  'CAINPH01': 'uncultured',
#  'CAINPL01': 'uncultured',
#  'CAINTH01': 'uncultured',
#  'CAINUV01': 'uncultured',
#  'CAII01': 'Microcystis',
#  'CAIJ01': 'Microcystis',
#  'CAINUW01': 'uncultured',
#  'CAINWI01': 'uncultured',
#  'CAINWT01': 'uncultured',
#  'CAIQXI01': 'uncultured',
#  'CAIRGI01': 'Synechococcus',
#  'CAIRHH01': 'uncultured',
#  'CAIRPA01': 'uncultured',
#  'CAIRRO01': 'uncultured',
#  'CAIRWM01': 'uncultured',
#  'CAISAU01': 'Synechococcus',
#  'CAISDG01': 'Synechococcus',
#  'CBZS01': 'Richelia',
#  'CAISIH01': 'uncultured',
#  'CADCTM01': 'uncultured',
#  'CADCTY01': 'uncultured',
#  'CAQK01': 'Crocosphaera',
#  'CAQL01': 'Crocosphaera',
#  'CAQM01': 'Crocosphaera',
#  'CAQN01': 'Crocosphaera',
#  'CDHJ01': 'Aphanizomenon',
#  'DLDG01': 'Aphanizomenon',
#  'DLDQ01': 'Aphanizomenon',
#  'DLEF01': 'Aphanizomenon',
#  'DLEZ01': 'Aphanizomenon',
#  'DLGM01': 'Aphanizomenon',
#  'DLLM01': 'Aphanizomenon',
#  'DLPW01': 'Aphanizomenon',
#  'DLSU01': 'Aphanizomenon',
#  'DLUV01': 'Aphanizomenon',
#  'DLXW01': 'Aphanizomenon',
#  'DLZW01': 'Aphanizomenon',
#  'DMEQ01': 'Aphanizomenon',
#  'DMJW01': 'Aphanizomenon',
#  'CADCTZ01': 'uncultured',
#  'CADCWO01': 'uncultured',
#  'DVDT01': 'uncultured',
#  'DVDU01': 'uncultured',
#  'DVDV01': 'uncultured',
#  'DVDW01': 'uncultured',
#  'DVDX01': 'uncultured',
#  'DVDY01': 'uncultured',
#  'DVDZ01': 'uncultured',
#  'DVEA01': 'uncultured',
#  'DVEB01': 'uncultured',
#  'DVEC01': 'uncultured',
#  'DVED01': 'uncultured',
#  'DVEE01': 'uncultured',
#  'DVEF01': 'uncultured',
#  'DPNP01': 'uncultured',
#  'DPOG01': 'uncultured',
#  'DQAX01': 'uncultured',
#  'DQEB01': 'uncultured',
#  'DOBT01': 'uncultured',
#  'DOFR01': 'uncultured',
#  'DOHO01': 'uncultured',
#  'DOIX01': 'uncultured',
#  'DOJB01': 'uncultured',
#  'DOMQ01': 'uncultured',
#  'DOPQ01': 'uncultured',
#  'DOPZ01': 'uncultured',
#  'DOQK01': 'uncultured',
#  'DORF01': 'uncultured',
#  'DORG01': 'uncultured',
#  'DOVM01': 'uncultured',
#  'DOVO01': 'uncultured',
#  'DOWB01': 'uncultured',
#  'DPEI01': 'uncultured',
#  'DPLL01': 'uncultured',
#  'DMPD01': 'uncultured',
#  'DMPE01': 'uncultured',
#  'DMPJ01': 'uncultured',
#  'DMXX01': 'uncultured',
#  'DMYK01': 'uncultured',
#  'DNGG01': 'uncultured',
#  'DNGI01': 'uncultured',
#  'DNGJ01': 'uncultured',
#  'DNLA01': 'uncultured',
#  'DNME01': 'uncultured',
#  'DNOV01': 'uncultured',
#  'DNOW01': 'uncultured',
#  'DNOY01': 'uncultured',
#  'DNOZ01': 'uncultured',
#  'DNRP01': 'uncultured',
#  'DNSU01': 'uncultured',
#  'DNUG01': 'uncultured',
#  'DNXU01': 'uncultured',
#  'DNYC01': 'uncultured',
#  'DNYD01': 'uncultured',
#  'DNYY01': 'uncultured',
#  'DNZA01': 'uncultured',
#  'DVEG01': 'uncultured',
#  'DVEH01': 'uncultured',
#  'DYNF01': 'uncultured',
#  'DSGY01': 'uncultured',
#  'DSMC01': 'uncultured',
#  'DSPK01': 'uncultured',
#  'DSPW01': 'uncultured',
#  'DSPX01': 'uncultured',
#  'DSQC01': 'uncultured',
#  'DBAX01': 'uncultured',
#  'DBCX01': 'uncultured',
#  'DBIX01': 'uncultured',
#  'DBVD01': 'uncultured',
#  'DBVH01': 'uncultured',
#  'DBXD01': 'uncultured',
#  'DBYM01': 'uncultured',
#  'DCNZ01': 'uncultured',
#  'DCQC01': 'uncultured',
#  'DCSN01': 'uncultured',
#  'DDLS01': 'uncultured',
#  'DFEL01': 'uncultured',
#  'DFQU01': 'uncultured',
#  'DFRI01': 'uncultured',
#  'DFVO01': 'uncultured',
#  'DFYB01': 'uncultured',
#  'DGBR01': 'uncultured',
#  'DGDG01': 'uncultured',
#  'DGDH01': 'uncultured',
#  'DIYQ01': 'uncultured',
#  'DIYT01': 'uncultured',
#  'DDVE01': 'uncultured',
#  'DEDY01': 'uncultured',
#  'DEEH01': 'uncultured',
#  'DEEN01': 'uncultured',
#  'DEFJ01': 'uncultured',
#  'DEGT01': 'uncultured',
#  'DEGZ01': 'uncultured',
#  'DESS01': 'uncultured',
#  'DESZ01': 'uncultured',
#  'DJOE01': 'uncultured',
#  'DJQF01': 'uncultured',
#  'DJYG01': 'uncultured',
#  'DJYZ01': 'uncultured',
#  'DKMR01': 'uncultured',
#  'DKOB01': 'uncultured',
#  'DKOE01': 'uncultured',
#  'DKRT01': 'uncultured',
#  'DGYA01': 'uncultured',
#  'DHMN01': 'uncultured',
#  'DSRD01': 'uncultured',
#  'DSRU01': 'uncultured',
#  'CAIJEA01': 'uncultured',
#  'CAIJFA01': 'uncultured',
#  'CAIJJB01': 'uncultured',
#  'CAJXSQ01': 'uncultured',
#  'CAJXVH01': 'uncultured',
#  'CAJWKD01': 'uncultured',
#  'ASSJ01': 'Rubidibacter',
#  'CAJWNL01': 'Rubidibacter',
#  'ASZQ01': 'Microcystis',
#  'CAJWON01': 'Microcystis',
#  'ATDS01': 'Sodalinema',
#  'CAJWSD01': 'Sodalinema',
#  'CAJWUF01': 'Sodalinema',
#  'BLJI01': 'Chroococcus',
#  'BLZO01': 'Okeania',
#  'JAABOT01': 'Synechocystis',
#  'JAABRE01': 'Synechococcales',
#  'BOWF01': 'Prochlorococcus',
#  'BOXC01': 'Synechococcus',
#  'BOXD01': 'Synechococcus',
#  'BOYO01': 'Prochlorococcus',
#  'AUMZ01': 'Synechococcus',
#  'AUNA01': 'Synechococcus',
#  'AUSW01': 'Psychrobacter',
#  'AUZM01': 'Lyngbya',
#  'AVFS01': 'Planktothrix',
#  'ARCP01': 'Filamentous',
#  'BOYP01': 'Synechococcus',
#  'AVFT01': 'Planktothrix',
#  'AVFU01': 'Planktothrix',
#  'AVFV01': 'Planktothrix',
#  'BPAC01': 'Synechococcus',
#  'AVFW01': 'Planktothrix',
#  'AVFX01': 'Planktothrix',
#  'AVFY01': 'Planktothrix',
#  'AVFZ01': 'Planktothrix',
#  'AWNH01': 'Leptolyngbya',
#  'FITM01': 'Synechococcus',
#  'FXBO01': 'Synechococcus',
#  'FXWN01': 'Synechococcus',
#  'FYBH01': 'Calothrix',
#  'JENA01': 'Synechococcus',
#  'JHEG04': 'Tolypothrix',
#  'UCNL01': 'Synechococcus',
#  'UCNM01': 'Synechococcus',
#  'JJML01': 'Neosynechococcus',
#  'AXAQ01': 'Mastigocoleus',
#  'JMIX01': 'Erythrobacter',
#  'JNAG01': 'Prochlorococcus',
#  'JNAH01': 'Prochlorococcus',
#  'JNAI01': 'Prochlorococcus',
#  'JNAJ01': 'Prochlorococcus',
#  'JNAK01': 'Prochlorococcus',
#  'JNAL01': 'Prochlorococcus',
#  'JNAM01': 'Prochlorococcus',
#  'JNAN01': 'Prochlorococcus',
#  'FSSI02': 'Oscillatoria',
#  'JNAO01': 'Prochlorococcus',
#  'JNAP01': 'Prochlorococcus',
#  'JAABRK01': 'Microcoleaceae',
#  'JAABRM01': 'Oscillatoriales',
#  'JAABSD01': 'Phormidium',
#  'JAABSJ01': 'Oscillatoria',
#  'JAABST01': 'Geitlerinema',
#  'JAABSU01': 'Spirulina',
#  'JAACDE01': 'Synechococcales',
#  'JAACPM01': 'Cyanobacteria',
#  'JAACQX01': 'Cyanobacteria',
#  'JAACSJ01': 'Cyanobacteria',
#  'JAACTD01': 'Cyanobacteria',
#  'JAACUG01': 'Cyanobacteria',
#  'CAJWVT01': 'Cyanobacteria',
#  'CAACVJ01': 'Hyella',
#  'JAAORC01': 'Prochlorococcus',
#  'JAAORD01': 'Prochlorococcus',
#  'JAAORE01': 'Prochlorococcus',
#  ...}

# %%
count = 0

for key in taxa_dict:
    if taxa_dict[key] == 'Fischerella':
        count += 1
        
count
# Out:
# 49

# %%
percent_col = []
new_name = []

for i,r in mash_df.iterrows():
    percent_col.append(int(r['matching-hashes'].split('/')[0])/10)
    ncbi_code = os.path.basename(r['reference'].split('.')[0])
    new_name.append(ncbi_code+'_'+taxa_dict[ncbi_code])
    
    
mash_df['percentage'] = percent_col
mash_df['reference'] = new_name

mash_df[:20]
# Out:
#                      reference           query  distance         pvalue  \
# 29          AJLJ01_Fischerella  ./CENA71.fasta  0.074070   0.000000e+00
# 62          ALVS01_Fischerella  ./CENA71.fasta  0.079484   0.000000e+00
# 2197       LIRN01_Hapalosiphon  ./CENA71.fasta  0.079901   0.000000e+00
# 67          ALVX01_Fischerella  ./CENA71.fasta  0.079901   0.000000e+00
# 2268      MNPM02_Mastigocladus  ./CENA71.fasta  0.081614   0.000000e+00
# 2321      NAPS01_Westiellopsis  ./CENA71.fasta  0.082054   0.000000e+00
# 3086  QLKN01_Hapalosiphonaceae  ./CENA71.fasta  0.083404   0.000000e+00
# 1959             JAHHHW01_MAG:  ./CENA71.fasta  0.086249   0.000000e+00
# 30          AJLK01_Fischerella  ./CENA71.fasta  0.126974  9.205260e-154
# 2404        NRQW01_Fischerella  ./CENA71.fasta  0.126974  6.184730e-154
# 1378      JACJRZ01_Fischerella  ./CENA71.fasta  0.126974  9.383780e-154
# 2377        NMQE01_Fischerella  ./CENA71.fasta  0.132399  5.367040e-136
# 2375        NMQC01_Fischerella  ./CENA71.fasta  0.133864  1.703880e-132
# 2383        NMQK01_Fischerella  ./CENA71.fasta  0.133864  8.864640e-131
# 2382        NMQJ01_Fischerella  ./CENA71.fasta  0.133864  2.594440e-131
# 2333        NGZU01_Fischerella  ./CENA71.fasta  0.135380  7.472280e-128
# 2341        NHAC01_Fischerella  ./CENA71.fasta  0.136948  3.053810e-123
# 26          AGIZ01_Fischerella  ./CENA71.fasta  0.136948  3.789730e-123
# 2346        NHAH01_Fischerella  ./CENA71.fasta  0.136948  3.666160e-123
# 2347        NHAI01_Fischerella  ./CENA71.fasta  0.136948  2.984100e-123
#
#      matching-hashes  percentage
# 29          118/1000        11.8
# 62          104/1000        10.4
# 2197        103/1000        10.3
# 67          103/1000        10.3
# 2268         99/1000         9.9
# 2321         98/1000         9.8
# 3086         95/1000         9.5
# 1959         89/1000         8.9
# 30           36/1000         3.6
# 2404         36/1000         3.6
# 1378         36/1000         3.6
# 2377         32/1000         3.2
# 2375         31/1000         3.1
# 2383         31/1000         3.1
# 2382         31/1000         3.1
# 2333         30/1000         3.0
# 2341         29/1000         2.9
# 26           29/1000         2.9
# 2346         29/1000         2.9
# 2347         29/1000         2.9

# %%
mash_df.to_csv("./mash_df_fischerella-220111.csv",sep='\t')

# %%
# !mkdir top_100

# %%
for genome in mash_df['reference'][:100]:
    subprocess.call('cp /Volumes/TFL210426/schneider/fasta_genomes/%s.fasta ./top_100/'%genome.split('_')[0],shell=True)

# %% [markdown]
# ## Extracting 16S rRNA

# %% [markdown]
# ```
# barrnap CENA71.fasta > barrnap_rRNAs.txt
# ```

# %%
def extract_nucleotides(fastafile,contig_name,start,end):
    if os.path.exists(fastafile):
        f = Fasta(fastafile)
        nucleotides = f[str(contig_name)][start:end]
    else:
        raise ValueError("Fasta file not found")
    return nucleotides

def fetch_barrnap_rRNA_genes(barrnap_df,rRNA,output_file):
    rRNA_options = ['5S','16S','23S']
    if rRNA not in rRNA_options:
        raise ValueError("Select '5S', '16S' or '23S' as the rRNA to be fetched")
    else:
        records = []
        for i,r in barrnap_df.iterrows():
            m = re.search(r'%s'%rRNA,barrnap_df.i.loc[i])
            if m:
                fastafile = "CENA71.fasta"
                if os.path.exists(fastafile):
                    nucleotides = extract_nucleotides(fastafile,barrnap_df.a.loc[i],
                                                      int(barrnap_df.d.loc[i]),int(barrnap_df.e.loc[i]))
                    seq = SeqRecord(Seq(nucleotides,generic_dna), id = "%s"%barrnap_df.a.loc[i], description="%s_gene"%rRNA)
                    records.append(seq)
                else:
                    raise ValueError("Fasta file %s not found"%fastafile)
    handle = open("%s"%output_file, "w")
    SeqIO.write(records,handle,"fasta")
    handle.close
    return records

def extract_rRNA_genes(df,barrnap_input,output_file,rRNA):
    if os.path.exists(output_file):
        print("%s genes fasta output already exists"%rRNA)
    else:
        start_time = time.time()
        records = fetch_barrnap_rRNA_genes(df,rRNA,output_file)
        count = len(records)
        print("%s %s genes extracted! Fasta files saved as %s and %s.ren.fasta."%(count,rRNA,output_file,
                                                                                  os.path.splitext(output_file)[0]))
        print('\n' + "--- %s seconds ---" %(time.time()-start_time))
        
barrnap_file = "/Users/tiagoferreiraleao/Dropbox/tiago-NAS/schneider/barrnap_rRNAs.txt"
barrnap_df = pd.read_csv(barrnap_file,names=list(string.ascii_lowercase)[0:9],sep='\t').dropna()

extract_rRNA_genes(barrnap_df,barrnap_file,"/Users/tiagoferreiraleao/Dropbox/tiago-NAS/schneider/barrnap_16S.fasta","16S")
# Out:
# 1 16S genes extracted! Fasta files saved as /Users/tiagoferreiraleao/Dropbox/tiago-NAS/schneider/barrnap_16S.fasta and /Users/tiagoferreiraleao/Dropbox/tiago-NAS/schneider/barrnap_16S.ren.fasta.
#
# --- 0.008651018142700195 seconds ---
